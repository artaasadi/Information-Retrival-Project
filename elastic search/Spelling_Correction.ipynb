# %% [markdown]
# # Spelling Correction
# Here we are going to implement a spelling correction system with Elasticsearch. It is recommended to read the [documentation](https://www.elastic.co/guide/en/elasticsearch/reference/current/search-suggesters.html) before starting this part of your project. There are three steps and in each of which we add a feature and make an improvement. For the implementations, we will use [Python Elasticsearch Client](https://elasticsearch-py.readthedocs.io/).
# Here is my email:
# <a.akhoundi79@gmail.com>
#
# Please contact me if there are any problems.

# %%
from elasticsearch import Elasticsearch
from elasticsearch import helpers
import json
from tqdm import tqdm
import re
from copy import deepcopy

# %% [markdown]
# In the beginning, We load the dataset and prepare it to upload to the index.

# %%
with open("IR_data_news_12k.json" , 'r') as f:
    data = json.load(f)

# %%
data
# Out:
# {'0': {'title': 'اعلام زمان قرعه کشی جام باشگاه های فوتسال آسیا',
#   'content': '\nبه گزارش خبرگزاری فارس، کنفدراسیون فوتبال آسیا (AFC) در نامه ای رسمی به فدراسیون فوتبال ایران و باشگاه گیتی پسند زمان\xa0 قرعه کشی جام باشگاه های فوتسال آسیا را رسماً اعلام کرد. بر این اساس 25 فروردین ماه 1401 مراسم قرعه کشی جام باشگاه های فوتسال آسیا در مالزی برگزار می شود. باشگاه گیتی پسند بعنوان قهرمان فوتسال ایران در سال 1400 به این مسابقات راه پیدا کرده است. پیش از این گیتی پسند تجربه 3 دوره حضور در جام باشگاه های فوتسال آسیا را داشته که هر سه دوره به فینال مسابقات راه پیدا کرده و یک عنوان قهرمانی و دو مقام دومی بدست آورده است. انتهای پیام/\n\n\n',
#   'tags': ['اعلام زمان',
#    'قرعه\u200cکشی',
#    'قرعه\u200cکشی جام',
#    'قرعه\u200cکشی جام باشگاه\u200cهای فوتسال',
#    'ای اف سی',
#    'گیتی پسند'],
#   'date': '3/15/2022 5:59:27 PM',
#   'url': 'https://www.farsnews.ir/news/14001224001005/اعلام-زمان-قرعه-کشی-جام-باشگاه-های-فوتسال-آسیا',
#   'category': 'sports'},
#  '1': {'title': 'سجادی :حضور تماشاگران در  لیگ برتر فوتبال تابع نظر فدراسیون  و سازمان لیگ است',
#   'content': '\nبه گزارش خبرگزاری فارس، سید حمید سجادی در حاشیه مراسم گرامیداشت روز جوان در جمع خبرنگاران در رابطه با عرضه سهام سرخابی\u200cها در بورس اظهار داشت: منتظر طی روند هستیم و بعدا اطلاع رسانی خواهیم کرد. وی در مورد حضور تماشاگران در مسابقات فوتبال اظهار داشت:\xa0حضور تماشاگران در\xa0 لیگ برتر فوتبال تابع نظر فدراسیون ،سازمان لیگ و ستاد ملی مبارزه با کرونا است. انتهای پیام/\n\n\n',
#   'tags': ['سجادی', 'لیگ', 'فدراسیون', 'وزیر ورزش'],
#   'date': '3/15/2022 5:30:07 PM',
#   'url': 'https://www.farsnews.ir/news/14001224000982/سجادی-حضور-تماشاگران-در-لیگ-برتر-فوتبال-تابع-نظر-فدراسیون-و-سازمان',
#   'category': 'sports'},
#  '2': {'title': 'محل برگزاری نشست\u200cهای خبری سرخابی\u200cها؛ مجیدی در سازمان لیگ، گل\u200cمحمدی در تمرین پرسپولیس',
#   'content': '\nبه گزارش خبرگزاری فارس، نشست خبری پیش از مسابقه سرمربیان دو تیم پرسپولیس و استقلال از هفته بیست و سوم لیگ برتر با\xa0 مدیریت سازمان لیگ و هماهنگی\xa0باشگاه میزبان( پرسپولیس)\xa0 به شرح زیر\xa0 برگزار می شود: چهارشنبه ۲۵ اسفند ساعت ۱۵ فرهاد مجیدی سرمربی استقلال در سازمان لیگ فوتبال ایران ساعت ۱۳:۳۰ یحیی گل محمدی سرمربی پرسپولیس در ورزشگاه شهید کاظمی مسابقه دو تیم روز پنجشنبه در ورزشگاه آزادی برگزار می شود. انتهای پیام/\n\n\n',
#   'tags': ['دربی 94',
#    'محل برگزاری',
#    'خبری سرخابی\u200cها',
#    'مجیدی',
#    'سازمان لیگ',
#    'گل محمدی',
#    'سرمربیان'],
#   'date': '3/15/2022 5:20:01 PM',
#   'url': 'https://www.farsnews.ir/news/14001224000971/محل-برگزاری-نشست\u200cهای-خبری-سرخابی\u200cها-مجیدی-در-سازمان-لیگ-گل\u200cمحمدی-در',
#   'category': 'sports'},
#  '3': {'title': 'ماجدی در نشست با صالحی امیری: امیدوارم در این دوره تیم  المپیک موفق شود',
#   'content': '\nبه گزارش خبرگزاری فارس،\xa0 سید رضا صالحی امیری رئیس کمیته ملی المپیک در دیدار با سید میرشاد ماجدی سرپرست فدراسیون فوتبال بر آمادگی این کمیته به منظور حمایت همه جانبه از تیم المپیک ایران و ضرورت پیش بینی برنامه های آماده سازی مناسب برای این تیم تاکید کرد و گفت: ضمن آرزوی موفقیت برای آقای ماجدی به عنوان چهره با اخلاق فوتبال و ورزش تمام تلاشمان این خواهد بود تا تیم امید و المپیک در محیطی آرام و بدون دغدغه آماده حضور در بازی های آسیایی شود، ضمن اینکه پیش از این هم اعلام کردیم دخالتی در امور فنی تیم ها نداشته و نخواهیم داشت. سرپرست فدراسیون فوتبال نیز با تاکید بر ضرورت تعامل و همکاری همه جانبه در خصوص برنامه ریزی و آماده سازی مناسب تیم المپیک گفت:تیم فوتبال زیر 23 سال ایران با حضور مهدی مهدوی کیا و اعضای کادر فنی همچنین از ظرفیت بسیار خوبی برای موفقیت در این دوره برخوردار است و هماهنگی و همکاری نزدیک کمیته ملی المپیک و فدراسیون فوتبال در راستای حمایت از این تیم با تامین خواسته های مورد نظر اعضای کادر فنی می تواند نتایج ارزشمندی به همراه داشته باشد. امیدواریم در این دوره شاهد موفقیت تیم المپیک و کسب نتایجی در شان و جایگاه فوتبال ملی ایران باشیم. در این نشست که با حضور نصرالله سجادی مشاور رئیس کمیته و\xa0 پیمان فخری سرپرست کاروان ورزشی اعزامی ایران به بازی های آسیایی ۲۰۲۲ هانگژو برگزار شد هماهنگی لازم در خصوص همکاری دو جانبه فدراسیون فوتبال و کمیته ملی المپیک در خصوص برنامه ها و اردوهای آماده سازی آتی تیم المپیک صورت پذیرفت. انتهای پیام/\n\n\n',
#   'tags': ['کمیته امداد امام خمینی (ره)',
#    'کمیته ملی المپیک',
#    'ماجدی',
#    'نشست',
#    'صالحی',
#    'تیم المپیک'],
#   'date': '3/15/2022 5:18:00 PM',
#   'url': 'https://www.farsnews.ir/news/14001224000964/ماجدی-در-نشست-با-صالحی-امیری-امیدوارم-در-این-دوره-تیم-المپیک-موفق',
#   'category': 'sports'},
#  '4': {'title': 'لیگ\u200cبرتر بسکتبال|\u200c نخستین پیروزی شهرداری گرگان و ذوب\u200cآهن در پلی\u200cآف',
#   'content': '\nبه گزارش خبرنگار ورزشی خبرگزاری فارس، در نخستین بازی از روز دوم مرحله پلی\u200cآف لیگ برتر بسکتبال، تیم\u200cهای شهرداری گرگان و اکسون مقابل هم به میدان رفتند که گرگانی\u200cها موفق شدند 80 بر 71 به برتری برسند. در این مسابقه پری پتی با کسب 26 امتیاز و 6 ریباند، پرامتیازترین بازیکن گرگان و میدان بود. در دیگر بازی برگزار شده ذوب آهن که با صدرنشینی به پلی\u200cآف رسیده بود، در دیدار با صنایع هرمزگان 73 بر 70 به برتری رسید. انتهای پیام/ \xa0 \xa0\n\n\n',
#   'tags': ['بسکتبال',
#    'لیگ برتر بسکتبال',
#    'شهرداری گرگان',
#    'تیم بسکتبال ذوب آهنگ'],
#   'date': '3/15/2022 5:16:41 PM',
#   'url': 'https://www.farsnews.ir/news/14001224000947/لیگ\u200cبرتر-بسکتبال|\u200c-نخستین-پیروزی-شهرداری-گرگان-و-ذوب\u200cآهن-در-پلی\u200cآف',
#   'category': 'sports'},
#  '5': {'title': 'مسابقات تنیس روی میز فیدر قطر| هر4 بانوی ملی پوش ایران حذف شدند',
#   'content': '\nبه گزارش خبرگزاری فارس، چهار بانوی تنیس روی میز ایران با باخت در مصاف با رقبای خود در جدول ۶۴ نفره رقابت\u200cهای فیدر دوحه قطر از راهیابی به مرحله بعد بازماندند. ندا شهسواری در مصاف با هوانگ با رنکینگ ۳۸۲ دنیا از چین تایپه با حساب ۴ بر صفر مغلوب شد. شهسواری در گیم اول ۱۱ بر ۷، گیم دوم ۱۱ بر ۲ و در دو گیم متوالی با حساب ۱۱ بر ۶ متوقف و از راهیابی به مرحله بعد بازماند. مهشید اشتری در مصاف با چانگ لی از مالزی با حساب ۴ بر ۲ شکست خورد. حریف اشتری دارنده رنک ۲۳۷ دنیا بود که نماینده کشورمان در دو گیم با حساب ۱۱ بر ۸ شکست خورد و \u200c گیم سوم ۱۱ بر ۷ به سود اشتری خاتمه یافت. گیم چهارم ۱۱ بر ۱۳ به سود حریف به اتمام رسید و اشتری در گیم چهارم ۱۳ بر ۱۱ برابر حریف به برتری دست یافت اما در پایان گیم ششم حریف مالزیایی ۱۲ بر ۱۰ از سد اشتری گذشت. مریم صامت در تقابل با النا از رومانی دارنده رنک ۲۱۵ با نتیجه ۴ بر ۳ شکست خورد. گیم اول ۱۱ بر ۷ به سود حریف به پایان رسید ، صامت در دو گیم متوالی ۱۱ بر ۶ و سپس ۱۱ بر ۷ به پیروزی دست یافت، حریف رومانیایی در گیم چهارم ۱۱ بر ۸ از سد صامت عبور کرد و بازی در گیم پنجم ۱۴ بر ۱۲ به نفع صامت خاتمه یافت. حریف در پایان گیم های ششم و هفتم با برتری ۱۱ بر ۵ از سد نماینده کشورمان عبور کرد. شیما صفایی با قبول شکست ۴ بر صفر مقابل نماینده هند از راهیابی به دور بعد بازماند. ۱۱ بر ۵ در گیم اول ، ۱۳ بر ۱۱ در گیم دوم، ۱۱ بر ۵ و ۱۱ بر ۹ نتایج رقم خورده در این دیدار به نفع حریف هندی صفایی بود. انتهای پیام/\n\n\n',
#   'tags': ['مهشید اشتری',
#    'تنیس روی میز',
#    'ملی پوشان تنیس روی میز در مسابقات قطر',
#    'ندا شهسواری'],
#   'date': '3/15/2022 5:15:34 PM',
#   'url': 'https://www.farsnews.ir/news/14001224000916/مسابقات-تنیس-روی-میز-فیدر-قطر|-هر4-بانوی-ملی-پوش-ایران-حذف-شدند',
#   'category': 'sports'},
#  '6': {'title': 'اعلام برنامه نشست خبری گل محمدی/ مجیدی هم باید به محل تمرین پرسپولیس برود!',
#   'content': '\nبه گزارش خبرگزاری فارس و به نقل از\xa0 سایت باشگاه پرسپولیس، نشست خبری پیش از مسابقه سرمربیان دو تیم پرسپولیس و استقلال از هفته بیست و سوم لیگ برتر (جام خلیج فارس) با\xa0 مدیریت سازمان لیگ و هماهنگی\xa0باشگاه میزبان (پرسپولیس) در ورزشگاه شهید کاظمی به شرح زیر\xa0 برگزار می\u200cشود: چهارشنبه ۲۵ اسفند ساعت ۱۳ فرهاد مجیدی سرمربی استقلال ساعت ۱۳:۳۰ یحیی گل محمدی سرمربی پرسپولیس \xa0مسابقه دو تیم روز پنجشنبه در ورزشگاه آزادی برگزار می\u200cشود. \xa0به گزارش خبرگزاری فارس، پیش از این باشگاه استقلال اعلام کرده بود قرار است نشست خبری فرهاد مجیدی، سرمربی این تیم از ساعت ۱۵ در سازمان لیگ برگزار شود. انتهای پیام /\n\n\n',
#   'tags': ['باشگاه استقلال',
#    'یحیی گل محمدی',
#    'فرهاد مجیدی',
#    'نشست خبری گل محمدی و مجیدی',
#    'دربی ۹۸',
#    'پرسپولیس'],
#   'date': '3/15/2022 3:57:47 PM',
#   'url': 'https://www.farsnews.ir/news/14001224000865/اعلام-برنامه-نشست-خبری-گل-محمدی-مجیدی-هم-باید-به-محل-تمرین-پرسپولیس',
#   'category': 'sports'},
#  '7': {'title': 'احضار مدیران پرسپولیس به کمیته انضباطی  پیش از دربی',
#   'content': '\nبه گزارش خبرنگار ورزشی خبرگزاری فارس، کمیته انضباطی فدراسیون فوتبال در روزهای اخیر با احضار دو مدیر پرسپولیس از آنها درخواست کرده با توجه به شکایت باشگاه استقلال مستندات خود را بابت شکایت استقلال ارائه کنند. مصطفی لشگری، مدیر روابط عمومی و علیرضا اشرف، مدیر رسانه\u200cای پرسپولیس دو مدیر این باشگاه هستند که باید توضیحات خود را در آستانه دربی به کمیته انضباطی ارائه کنند.البته رضا درویش، مدیرعامل پرسپولیس هم بابت برخی بیانیه\u200cهای این تیم به کمیته انضباطی احضار شده است. البته گفته می شود این قضیه در مورد مدیران باشگاه استقلال هم اتفاق افتاده است. انتهای پیام /\n\n\n',
#   'tags': ['باشگاه پرسپولیس',
#    'احضار مدیران پرسپولیس به کمیته انضباطی',
#    'فدراسیون فوتبال',
#    'کمیته انضباطی فدراسیون فوتبال'],
#   'date': '3/15/2022 3:43:18 PM',
#   'url': 'https://www.farsnews.ir/news/14001224000842/احضار-مدیران-پرسپولیس-به-کمیته-انضباطی-پیش-از-دربی',
#   'category': 'sports'},
#  '8': {'title': 'مدیر بی\u200cدستاورد، رئیس شد/ روزگار تلخ\u200cتر از تلخ برای والیبال ارومیه؟',
#   'content': '\nبه گزارش خبرنگار ورزشی خبرگزاری فارس، مجمع انتخاباتی ریاست هیات والیبال ارومیه روز سه\u200cشنبه با رقابت بین مهدی احمدی، پیمان رضایی و آیدین رحمانی برگزار شد. در پایان این رقابت انتخاباتی پیمان رضایی با کسب 20 رای به عنوان رئیس هیات والیبال ارومیه انتخاب شد. همچنین رحمانی 9 رای آورد و اعضای حاضر به احمدی رای ندادند. انتخاب پیمان رضایی به عنوان رئیس جدید هیات والیبال ارومیه در حالی است که وی در مدت حضورش در سمت مدیر عامل باشگاه شهرداری ارومیه نتوانست به توفیق خاصی دست پیدا کند و بهترین مقام ارومیه نایب قهرمانی در لیگ برتر است. علاوه بر این موضوعات جای سوال دارد که چرا در انتخابات ریاست هیأت والیبال شهری مانند ارومیه خبری از پیشکسوتان و چهره\u200cهای شناخته شده نبوده است؟ رضایی در شرایطی توانست به عنوان رئیس هیأت والیبال انتخاب شود که در روزهای اخیر علی\u200cاصغر مجرد، ملی\u200cپوش والیبال کشورمان در گفت\u200cوگو با خبرنگار ورزشی خبرگزاری فارس نکات عجیبی از مدل مدیریتی وی را افشا کرد.\xa0  مجرد در بخشی از اظهارات خود عنوان کرد:\xa0لیاقت مردم ارومیه خیلی بالا است. من در جایگاهی نیستم که بخواهم درمورد مردم و والیبال ارومیه حرف بزنم، اما امثال این آقا اینقدر به مردم دروغ گفته\u200cاند و خرابکاری کرده\u200cاند، عملاً لطمه\u200cهای بزرگی به والیبال ارومیه زده\u200cاند وگرنه آن شهر باید تاکنون 10 قهرمانی لیگ برتر را تجربه می\u200cکرد و به جام باشگاه\u200cهای آسیا و جهان می\u200cرفت، نه اینکه میزبانی جام باشگاه\u200cهای آسیا را هم از آن شهر بگیرند. برخی\u200cها از آن باشگاه به من گفتند که ما هنوز بدهی تراویسای پدر و پسر و بازیکن فنلاندی سابق خود را هم نداده\u200cایم؛ قرارداد تو هم نهایتاً به آنها اضافه خواهد شد.\xa0 درهمین راستا چندی پیش هم فدراسیون جهانی و کنفدراسیون والیبال آسیا میزبانی مسابقات جام باشگاه\u200cهای آسیا در سال 2022 را به ایران اهدا کردند و فدراسیون کشورمان هم تصمیم گرفت ارومیه را به عنوان میزبان این رقابت\u200cها انتخاب کند، اما موضوع مهمی که وجود داشت این بود که تیم شهرداری ارومیه به عنوان میزبان این بازی\u200cها حق حضور نداشت، چراکه این باشگاه بعد از سال\u200cها بدهی خود را تراویسا را تسویه نکرده بود. گفته می\u200cشد باشگاه شهرداری ارومیه مبلغی حدود 15 میلیارد تومان را باید به تراویسای پدر و پسر پرداخت کند تا شاید محرومیتش بخشیده شود؛ اما هیچ عزمی برای پرداخت این بدهی از سوی مسئولان ارومیه دیده نشد تا اینکه میزبانی از ارومیه گرفته شد و به تهران رسید. در همان مقطع پیمان رضایی، مدیرعامل باشگاه شهرداری ارومیه پس از پیگیری\u200cهای مکرر خبرنگار ورزشی خبرگزاری فارس برای اطلاع از آخرین شرایط این پرونده، اظهار داشت: فعلاً جلسه دارم و هر زمانی که خودم صلاح بدانم با شما تماس خواهم گرفت!  در آن زمان هواداران والیبال در ارومیه حاضر بودند دست به دست هم داده و از جیب خودشان هم که شده این بدهی را جمع\u200cآوری و پرداخت کنند تا شاهد درخشش تیم\u200cشان در مسابقات جام باشگاه\u200cهای آسیا باشند، اما رضایی و همکارانش ترجیح می\u200cدادند جلسات بدون خروجی برگزار کرده و از پاسخگویی به اصحاب رسانه طفره بروند.\xa0 به این ترتیب پیمان رضایی حالا قرار است در هیأت والیبال فعالیت خود را دنبال کند. این اتفاق در شرایطی در حال رخ دادن است که تیمداری شهرداری ارومیه در فصل آینده لیگ برتر والیبال هم در هاله\u200cای از ابهام قرار دارد. عاشقان والیبال ارومیه توقع دارند که مسئولان با احساسات آنها بازی نکرده و به فکر رشد و توسعه این رشته در پایتخت والیبال آسیا باشند. با این شرایط باید منتظر ماند و دید، آیا رضایی که در دوران مدیریتش لطمه\u200cهای زیادی به والیبال ارومیه وارد شد، می\u200cتواند تغییر نقش داده و ناجی باشد یا همچنان به عنوان نابودگر به فعالیت خود ادامه خواهد داد؟\xa0 انتهای پیام/\n\n\n',
#   'tags': ['والیبال',
#    'پیمان رضایی',
#    'تیم والیبال شهرداری ارومیه',
#    'انتخاب والیبال ارومیه',
#    'هیأت والیبال ارومیه',
#    'باشگاه شهرداری ارومیه'],
#   'date': '3/15/2022 3:35:21 PM',
#   'url': 'https://www.farsnews.ir/news/14001224000811/مدیر-بی\u200cدستاورد-رئیس-شد-روزگار-تلخ\u200cتر-از-تلخ-برای-والیبال-ارومیه',
#   'category': 'sports'},
#  '9': {'title': 'خبر خوب برای استقلال؛ دانشگر با تیم تمرین کرد',
#   'content': '\nبه گزارش خبرنگار ورزشی خبرگزاری فارس، تمرین امروز استقلال در شرایطی برگزار شد که محمد دانشگر مدافع مصدوم این تیم در تمرینات گروهی تیمش شرکت کرد. این بازیکن روز گذشته در تمرین تیمش فقط به برنامه\u200cهای اختصاصی پرداخت و به صورت سبک تمرین کرد اما امروز در تمرین گروهی تیمش حضور داشت. تیم فوتبال استقلال برای دربی روز پنجشنبه آماده می\u200cشود. انتهای پیام/ \xa0\n\n\n',
#   'tags': ['دانشگر با تیم تمرین کرد', 'محمد دانشگر', 'استقلال'],
#   'date': '3/15/2022 3:21:04 PM',
#   'url': 'https://www.farsnews.ir/news/14001224000819/خبر-خوب-برای-استقلال-دانشگر-با-تیم-تمرین-کرد',
#   'category': 'sports'},
#  '10': {'title': 'تراکتور در آستانه بازگشت به خانه اصلی/ نواقص ورزشگاه یادگار امام بررسی شد',
#   'content': '\nبه گزارش خبرگزاری فارس و به نقل از سایت باشگاه تراکتور، میر معصوم سهرابی، مدیرعامل این باشگاه به همراه نمایندگانی از استانداری آذربایجان شرقی، معاون عملیات نیروی انتظامی استان، نمایندگانی از یگان ویژه استان، مدیرکل ورزش و جوانان استان، نماینده اداره ورزش و جوانان شهرستان تبریز و مدیر ورزشگاه یادگار امام امروز (سه شنبه ۲۴ اسفند) از بخش\u200cهای مختلف ورزشگاه یادگار امام (ره) تبریز بازدید کرده و آخرین وضعیت و نواقصات این مجموعه برای میزبانی از هواداران تراکتور را بررسی کردند.  طی این بازدید، تمهیدات لازم در راستای آماده\u200cسازی این ورزشگاه برای میزبانی از بازی\u200cهای تیم تراکتور اندیشیده شد. انتهای پیام/\n\n\n',
#   'tags': ['باشگاه تراکتور',
#    'بازدید از ورزشگاه تراکتور',
#    'تیم تراکتور',
#    'ورزشگاه یادگار امام تبریز'],
#   'date': '3/15/2022 3:12:28 PM',
#   'url': 'https://www.farsnews.ir/news/14001224000804/تراکتور-در-آستانه-بازگشت-به-خانه-اصلی-نواقص-ورزشگاه-یادگار-امام-بررسی',
#   'category': 'sports'},
#  '11': {'title': 'تورنمنت شش جانبه تایلند| پیروزی پر گل  فوتسالیست\u200cهای  جوان ایران برابر مغولستان',
#   'content': '\n\xa0به گزارش خبرنگار ورزشی خبرگزاری فارس، تورنمنت ۶ جانبه فوتسال تایلند از روز گذشته با حضور تیم\u200cهای ایران، تایلند، عمان، میانمار، مالدیو و مغولستان در حال برگزاری است. تیم ملی فوتسال زیر ۱۹ سال کشورمان که در این تورنمنت حضور دارد در اولین بازی خود امروز\xa0 به مصاف مغولستان رفت و توانست این تیم را با نتیجه ۸ بر صفر شکست دهد. انتهای پیام/\n\n\n',
#   'tags': ['تورنمت ۶جانبه',
#    'گل فوتسالیست\u200cهای جوان',
#    'مغولستان',
#    'جانبه تایلند'],
#   'date': '3/15/2022 3:10:29 PM',
#   'url': 'https://www.farsnews.ir/news/14001224000800/تورنمنت-شش-جانبه-تایلند|-پیروزی-پر-گل-فوتسالیست\u200cهای-جوان-ایران-برابر',
#   'category': 'sports'},
#  '12': {'title': 'گزارش تمرین پرسپولیس| روحیه بالای شاگردان گل محمدی در آستانه دربی',
#   'content': '\nبه گزارش خبرگزاری فارس، تمرین امروز تیم فوتبال پرسپولیس از ساعت 11:45 در هوای مطبوع ورزشگاه شهید کاظمی زیر نظر کادر فنی با شادابی و روحیه بالای سرخ پوشان برگزار شد. * بازیکنان ابتدا زیر نظر مربی بدنساز تیم با انجام حرکات کششی، نرمشی و دوهای کوتاه، بدن\u200cها را گرم و در اختیار کادر فنی قرار گرفتند. * سپس در قالب سه گروه به تمرین پرداخته و در ادامه نیز مرور کارهای تاکتیکی و فوتبال هدفمند در دستور کار قرار گرفت. * تمرین امروز حدود 50 دقیقه به طول انجامید و کلیه سرخپوشان به جز سیامک نعمتی در برنامه\u200cهای کادر فنی حاضر بودند. در پایان نیز بازیکنان بدن\u200cها را سرد و راهی رختکن شدند. تیم پرسپولیس از ساعت 17:30 پنجشنبه در چارچوب دیدارهای هفته بیست و سوم لیگ برتر به مصاف استقلال می رود. انتهای پیام/\n\n\n',
#   'tags': ['باشگاه استقلال', 'باشگاه پرسپولیس', 'دربی 94', 'تمرین پرسپولیس'],
#   'date': '3/15/2022 3:02:45 PM',
#   'url': 'https://www.farsnews.ir/news/14001224000789/گزارش-تمرین-پرسپولیس|-روحیه-بالای-شاگردان-گل-محمدی-در-آستانه-دربی',
#   'category': 'sports'},
#  '13': {'title': 'پولادگر: درخشش\u200cهای هندبال مایه آبرو و اعتبار بین\u200cالمللی است/ پاکدل: زودتر از برنامه به اهداف خود رسیدیم',
#   'content': '\nبه گزارش خبرنگار ورزشی خبرگزاری فارس، مجمع فوق\u200cالعاده فدراسیون هندبال به ریاست دکتر سید محمد پولادگر معاون وزیر ورزش و جوانان و با حضور دیگر اعضا امروز (سه\u200cشنبه) در سالن استاد فارسی آکادمی ملی المپیک به صورت حضور و آنلاین برگزار شد. در این مجمع که با حضور سید محمد پولادگر به عنوان نماینده وزارت ورزش و جوانان، فضل\u200cالله باقرزاده به عنوان نماینده کمیته ملی المپیک، نصرالله پریچهره مدیرکل دفتر امور مشترک فدراسیون\u200cهای ورزشی، علیرضا پاکدل رئیس فدراسیون هندبال، دبیر و نواب رئیس فدراسیون و دیگر اعضای مجمع برگزار شد موارد مرتبط با تصویب اساس\u200cنامه فدراسیون\u200cهای ورزشی و همچنین دستورالعمل کمیسیون\u200cهای فدراسیون مورد بررسی و تصویب قرار گرفت. در این مجمع اساس نامه فدراسیون\u200cهای ورزشی، دستورالعمل کمیسیون\u200cهای ورزشکاران، مربیان، داوران و همچنین برنامه عملیاتی ۱۴۰۱ با اکثریت آرا مورد تصویب اعضای مجمع قرار گرفت. پاکدل: زودتر از برنامه به اهداف خود رسیدیم علیرضا پاکدل رئیس فدراسیون هندبال در این مجمع با اشاره به اتفاقات رخ داده در سال جاری برای هندبال ایران اظهار کرد: در طول سالی که گذشت شاهد رخ دادن اتفاقات بسیار مهمی در هندبال ایران بودیم که از جمله آنها باید به کسب سهمیه مسابقات جهانی توسط سه تیم ملی هندبال اشاره کرد.  وی افزود: روز گذشته تیم ملی جوانان دختر ایران توانستند تاریخ\u200cسازی کنند و علاوه بر عنوان نایب قهرمانی آسیا سهمیه مسابقات قهرمانی جهان را نیز بدست بیاورند. این سومین تیم ملی هندبال ایران در سال 1400 است که سهمیه جهانی را کسب می\u200cکند و باید این اتفاق ارزشمند را به جامعه هندبال تبریک بگویم. رئیس فدراسیون هندبال همچنین خطاب به اعضای مجمع گفت: بی تردید اگر حمایت و همدلی اعضای خانواده بزرگ هندبال ایران و حمایت\u200cهای اعضای مجمع نبود شاهد رخ دان این اتفاقات ارزشمند نبودیم. نکته قابل توجه اینجاست که ما هم اکنون بسیار زودتر از برنامه عملیاتی و چشم\u200cاندازی که داشتیم به اهداف خود دست پیدا کردیم. امروزبه واسطه جهانی شدن شیردختران ایران پشتوانه بسیار خوبی برای هندبال بانوان ساخته شده است و امیدوارم در روزهای پیش رو شاهد جهانی شدن هندبال نوجوانان دختر و همچنین تیم ملی ساحلی باشیم. پاکدل به میزبانی ایران از رقابت\u200cهای هندبال ساحلی قهرمانی آسیا نیز اشاره کرد و گفت: خوشبختانه در ادامه اتفاقات خوبی که برای هندبال ایران در حال رخ دادن است، شاهد میزبانی از رقابت\u200cهای قهرمانی آسیا در رشته هندبال ساحلی هستیم و ایام آغازین سال آینده با یک میزبانی مهم بین\u200cالمللی در کشور گره خورده است رئیس فدراسیون هندبال همچنین به جذب حامی مالی فدراسیون در سال جاری اشاره کرد و گفت: از آغاز فعالیت مشکلات زیادی در بخش مالی داشتیم که تلاش نمودیم تا این مشکلات را برطرف نماییم و امسال نیز شاهد حضور یک حامی مالی بزرگ در فدراسیون هندبال بودیم. در این شرایط با حضور حامی مالی دست هندبال گرفته شده است. ما در سال 1400 اعزام\u200cهای زیادی داشتیم و حضور این حامی مالی کمک زیادی به ما کرد. پولادگر: درخشش\u200cهای اخیر هندبال مایه آبرو و اعتبار بین\u200cالمللی است همچنین سید محمد پولادگر، معاون ورزش حرفه\u200cای و قهرمانی وزارت ورزش و جوانان که عهده\u200cدار ریاست مجمع بود در این نشست اظهار کرد: باید تبریک ویژه\u200cای به مناسبت موفقیت\u200cهای اخیر هندبال ایران داشته باشیم. موفقیت اخیر دختران ایران آبرو و اعتبار را برای ورزش ایران در عرصه\u200cهای بین\u200cالمللی و جهانی رقم زد.  وی افزود: در سال\u200cهای اخیر با مدیریت هوشمندانه فدراسیون هندبال و در راس آن آقای علیرضا پاکدل به عنوان رئیس فدراسیون و تدبیرهای فدراسیون شاهد سال\u200cهای پر از توفیق و درخشش برای هندبال هستیم. همچنین با این همدلی و وفاقی که در خانواده بزرگ هندبال وجود دارد بی\u200cتردید در میادین پیش رو شاهد موفقیت\u200cهای بیشتری خواهیم بود. معاون وزیر ورزش و جوانان خاطر نشان کرد: امیدوارم این وفاق و همدلی همچنان در هندبال ایران ادامه داشته باشد تا با موفقیت\u200cهای بیشتر شاهد سربلندی ایران اسلامی باشیم و برای این سربلندی همه باید تلاش کنیم. پولادگر با اشاره به موفقیت\u200cهای هندبال ایران در سال جاری خاطر نشان کرد: در حوزه ورزش بانوان شاهد بیشتر تبلیغات منفی از سوی دشمنان هستیم اما موفقیت\u200cهای بدست آمده در ورزش بانوان نظیر موفقیت بانوان هندبال نشان داد که محدودیتی در این حوزه نداریم و جمهوری اسلامی ایران شرایط یکسانی را برای مردان و زنان در ورزش فراهم نموده است. نکته قابل توجه این است که گاهی شرایط بهتری برای بانوان وجود دارد و مصد ...
#   'tags': ['مجمع عمومی فدراسیون هندبال',
#    'فدراسیون هندبال',
#    'هندبال ایران',
#    'محمد پولادگر',
#    'علیرضا پاکدل',
#    'هندبال'],
#   'date': '3/15/2022 2:51:45 PM',
#   'url': 'https://www.farsnews.ir/news/14001224000731/پولادگر-درخشش\u200cهای-هندبال-مایه-آبرو-و-اعتبار-بین\u200cالمللی-است-پاکدل-',
#   'category': 'sports'},
#  '14': {'title': 'جدایی ستاره منچستریونایتد تایید شد / کاوانی به بارسلونا می\u200cآید؟',
#   'content': '\nبه گزارش خبرگزاری فارس، فابریزیو رومانو در آخرین خبر خود اطلاع داد که «ادینسون کاوانی» در پایان فصل از جمع منچستریونایتد جدا خواهد شد. رومانو نوشت که کاوانی پس از 2 سال بازی در تیم لیگ برتری خواهان جدایی است و می\u200cخواهد روزهای خود را در لیگ اسپانیا سپری کند.\xa0 ستاره اروگوئه\u200cای 2 سال گذشته از پاری سن ژرمن راهی منچستریونایتد شد و توانست در 55 بازی آمار 19 گل و 7 پاس گل را به ثبت رساند. خبرنگار مشهور اسپانیایی عنوان کرد که کاوانی خواهان رسیدن به لالیگا است و با توجه به تیم\u200cهای موجود می\u200cتوان بارسلونا را یکی از گزینه\u200cهای خرید این مهاجم دانست. بارسا پیشتر نیز علاقه داشت که کاوانی را به خدمت گیرد و می\u200cتوان انتظار داشت اگر این تیم در جذب هالند ناکام بماند، شاید برای انتقال کاوانی جدی\u200cتر شود. انتهای پیام/\n\n\n',
#   'tags': ['کاوانی',
#    'ادینسون کاوانی',
#    'لیگ برتر انگلیس',
#    'منچستریونایتد',
#    'بارسلونا'],
#   'date': '3/15/2022 2:15:32 PM',
#   'url': 'https://www.farsnews.ir/news/14001224000708/جدایی-ستاره-منچستریونایتد-تایید-شد--کاوانی-به-بارسلونا-می\u200cآید',
#   'category': 'sports'},
#  '15': {'title': 'سنت شکنی پرسپولیس قبل از دربی/ شاگردان گل محمدی از امشب به اردو می\u200cروند',
#   'content': '\nبه گزارش خبرنگار ورزشی خبرگزاری فارس، تیم فوتبال پرسپولیس از ساعت 17:30 پنجشنبه در نود و هشتمین دربی پایتخت به مصاف استقلال خواهد رفت. طبق نظر یحیی گل\u200cمحمدی، سرمربی پرسپولیس بازیکنان این تیم از امشب اردوی پیش بازی خود را برگزار خواهند کرد تا با توجه به اهمیت دربی، در 48 ساعت باقی\u200cمانده تا این بازی، تمرکز بیشتری برای تقابل با رقیب سنتی داشته باشند. این در شرایطی است که سرخ\u200cپوشان اردوی پیش از بازی رفت خود با استقلال را مانند سایر دیدارهای این فصل، 24 ساعت مانده به شروع مسابقه برگزار کردند. انتهای پیام/\n\n\n',
#   'tags': ['باشگاه استقلال',
#    'باشگاه پرسپولیس',
#    'دربی 98',
#    'اردوی پرسپولیس قبل از دربی'],
#   'date': '3/15/2022 1:11:23 PM',
#   'url': 'https://www.farsnews.ir/news/14001224000590/سنت-شکنی-پرسپولیس-قبل-از-دربی-شاگردان-گل-محمدی-از-امشب-به-اردو',
#   'category': 'sports'},
#  '16': {'title': 'اعلام اسامی داوران هفته بیست و دوم لیگ دسته اول',
#   'content': '\nبه گزارش خبرگزاری فارس و به نقل از سایت فدراسیون فوتبال،اسامی داوران قضاوت کننده در دیدارهای هفته بیست و دوم لیگ دسته اول فوتبال از سوی کمیته داوران مشخص شد. تیم داوری این مسابقات به شرح زیر است: *چهارشنبه 25 اسفند شهرداری آستارا\xa0–\xa0شاهین شهرداری بوشهر محمدباقر پورباقر – محمد شاکر – احمد کاظم لو – مهدی نورمحمدی ناظر: ابوالحسن شیرازی مس شهر بابک\xa0–\xa0شمس آذر قزوین محمد ممتاز – احمد آریک – امیر امیری – احمد مرشدی ناظر: عبدالمجید معماری خیبر خرم آباد\xa0–\xa0سایپا تهران عباس راکی – جمیل محمدنیا – موسی وصال – ایمان شاه ولی ناظر: مهرداد ذهبی رایکا بابل\xa0–\xa0شهرداری همدان عبدالحسین باستان – مهدی سیفی – میلاد قنبری – حامد سیری ناظر: حسین طالقانی قشقایی شیراز\xa0–\xa0ماشین سازی تبریز معین ایزدی – امیررضا آشور ماهانی – احد سلطانی – احسان اکبری ناظر: مجید شمس ویستا توربین تهران\xa0–\xa0آرمان گهر سیرجان علی ابراهیمی – حامد تازه پور – آرش امینی – عنایت قوچ کانلو ناظر: محمدحسن ابراهیمی مس کرمان\xa0–\xa0خوشه طلایی ساوه مجتبی شجاعی – رضا حیدری – سجاد ایرانپور – علی سام ناظر: قاسم واحدی استقلال خوزستان\xa0–\xa0استقلال ملاثانی علی بای – مجتبی غریب – کورش صارمی -\xa0 هادی علی نیافرد ناظر: سعادت اله باغبان پارس جنوبی جم\xa0–\xa0ملوان بندرانزلی مهدی اجاقی – وحید سیفی – ابراهیم نیکنام – حامد صادقی جو ناظر: جواد شرفی انتهای پیام/\n\n\n',
#   'tags': ['داوران لیگ دسته اول', 'لیگ دسته اول', 'هفته بیست و دوم'],
#   'date': '3/15/2022 12:36:50 PM',
#   'url': 'https://www.farsnews.ir/news/14001224000524/اعلام-اسامی-داوران-هفته-بیست-و-دوم-لیگ-دسته-اول',
#   'category': 'sports'},
#  '17': {'title': 'ایده منچستریونایتد برای بازی مقابل سیمئونه +عکس',
#   'content': '\nبه گزارش خبرگزاری فارس، امشب در چارچوب دور برگشت یک هشتم نهایی لیگ قهرمانان اروپا، منچستریونایتد در اولدترافورد میزبان اتلتیکومادرید خواهد بود. دیدار رفت این 2 تیم با تساوی یک بر یک به پایان رسید و باید کدام تیم راهی مرحله بعدی خواهد شد. منچستریونایتد با پیروزی مقابل تاتنهام با انگیزه زیادی پا به این مسابقه خواهد گذاشت و می\u200cخواهد با استفاده از کریستیانو رونالدو، اتلتیکومادرید را در انگلیس زمین\u200cگیر کند. از امسال قانون گل زده در خانه حریف نیز دیگر برداشته شده و باید دید چه تیمی می\u200cتواند در طول بازی گل بیشتری به ثمر رساند.  ساموئل لوکهارست، خبرنگار مشهور نشریه منچسترایونینگ\u200cنیوز در گزارشی نوشت که رانگنیک با ایده بازی با تاتنهام وارد مسابقه خواهد شد. تنها تغییر بازگشت برونو فرناندز به ترکیب اصلی خواهد بود و این ستاره پرتغالی جانشین رشفورد در این مسابقه خواهد شد. برونو بازی مقابل تاتنهام را به دلیل کرونا از دست داده بود ولی برای این مسابقه در دسترس است. لوکهارست نوشت که رانگنیک از زوج «واران و مگوایر» در میانه خط دفاعی و از تلس و دالو در کناره\u200cها استفاده خواهد کرد زیرا این بازیکنان در بازی مقابل تاتنهام نمایش خوبی داشتند و قابل جایگزین نخواهند بود. ماتیچ که در بازی رفت نمایشی تحسین\u200cبرانگیز از خود نشان داد قطعا در ترکیب خواهد بود و فرد نیز یکی عناصر کلیدی رانگنیک در بازی نام خواهد گرفت. ترکیب احتمالی با سیستم 1-3-2-4 به شرح زیر است: دروازه\u200cبان: دیوید دخیا مدافعان: واران – مگوایر – تلس – دالو هافبک\u200cها: ماتیچ – فرد – برونو – پوگبا (وینگر چپ) و سانچو (وینگر راست) مهاجم: کریستیانو رونالدو  انتهای پیام/ \xa0\n\n\n',
#   'tags': ['منچستریونایتد', 'برونو فرناندز', 'رونالدو', 'منچستر یونایتد'],
#   'date': '3/15/2022 12:35:22 PM',
#   'url': 'https://www.farsnews.ir/news/14001224000514/ایده-منچستریونایتد-برای-بازی-مقابل-سیمئونه-عکس',
#   'category': 'sports'},
#  '18': {'title': 'مجیدی به محل نشست خبری پرسپولیس نمی\u200cرود/ اعلام برنامه کنفرانس خبری سرمربی استقلال',
#   'content': '\nبه گزارش خبرگزاری فارس،\xa0نشست خبری فرهاد مجیدی سرمربی تیم استقلال، پیش از دربی تهران؛ روز چهارشنبه ۲۵ اسفند، ساعت ۱۵ در محل سازمان لیگ در میدان شیخ\u200cبهایی برگزار خواهد شد. در نیم فصل اول نشست خبری سرمربی استقلال در هتل اسپیناس برگزار شد و حمید مطهری مربی پرسپولیس در محل دیگری پاسخگوی خبرنگاران شد. با توجه به این اتفاق سرمربی تیم استقلال در نشست خبری به میزبانی باشگاه پرسپولیس شرکت نمی\u200cکند و در سازمان لیگ پاسخگوی رسانه\u200cها خواهد بود. دیدار استقلال و پرسپولیس ساعت 17:30 روز پنجشنبه برگزار می\u200cشود. انتهای پیام/ \xa0\n\n\n',
#   'tags': ['باشگاه استقلال', 'فرهاد مجیدی', 'نشست خبری', 'یحیی گل\u200cمحمدی'],
#   'date': '3/15/2022 12:23:12 PM',
#   'url': 'https://www.farsnews.ir/news/14001224000502/مجیدی-به-محل-نشست-خبری-پرسپولیس-نمی\u200cرود-اعلام-برنامه-کنفرانس-خبری',
#   'category': 'sports'},
#  '19': {'title': 'بارسلونا با بازیکن میلان به توافق رسید / 3 مدافع رایگان در لیست ژاوی',
#   'content': '\nبه گزارش خبرگزاری فارس، جرارد رومرو، خبرنگار اسپانیایی از توافق «فرانک کسیه» با بارسلونا خبر داد. این بازیکن ساحل عاجی علاقه ندارد با میلان قرارداد خود را تمدید کند و به همین دلیل تصمیم گرفته در پایان فصل به صورت بازیکن آزاد راهی بارسلونا شود.\xa0 کسیه در خط میانی روسونری نمایش خوبی در این 2 فصل اخیر داشت. او به یکی از مهره\u200cهای بزرگ پیولی نام گرفته و توانسته در این فصل 29 بازی انجام دهد.\xa0 بارسلونا در تابستان قصد دارد برای جذب بازیکنان آزادی مثل کریستینسن و آزپیلیکوئتا (مدافعان چلسی) و نصیر مزروعی (دفاع راست آژاکس) تلاش کند. طبق گزارش\u200cها کریستینسن نیز با آبی\u200cاناری\u200cها به توافق رسیده و به احتمال فراوان راهی نیوکمپ خواهد شد. آبی\u200cاناری\u200cها تمام ثروت و توان خود را گذاشته\u200cاند تا در پنجره نقل و انتقالات تابستانی «ارلینگ هالند» را خریداری کنند. طبق گزارش\u200c رسانه\u200cهای اروپایی در چند اخیر منچسترسیتی اصلی\u200cترین گزینه انتقال این بازیکن است.\xa0 انتهای پیام/\n\n\n',
#   'tags': ['بارسلونا',
#    'کسیه',
#    'فرانک کسیه',
#    'کریستینسن',
#    'نقل و انتقالات بارسلونا'],
#   'date': '3/15/2022 12:15:09 PM',
#   'url': 'https://www.farsnews.ir/news/14001224000487/بارسلونا-با-بازیکن-میلان-به-توافق-رسید--3-مدافع-رایگان-در-لیست-ژاوی',
#   'category': 'sports'},
#  '20': {'title': 'واکنش اهالی تنیس به تبعیض نژادی/نادال: باید برای سختی\u200cها آماده باشیم',
#   'content': '\nبه گزارش خبرگزاری فارس، در جریان مسابقات تنیس ایندین ولز زمانی که نائومی اوساکا در حال مسابقه بود یکی از تماشاگران با صحبت\u200cهایی علیه وی، رفتار نژادپرستانه از خود نشان داد که همین موضوع واکنش اهالی تنیس را به دنبال داشت. بعد از حمایت\u200cهای اندی ماری، امروز رافائل نادال تنیسور مطرح اسپانیایی صحبت\u200cهایی را در جهت دفاع از اوساکا داشت. وی عنوان کرد: برای اتفاقی که افتاد بسیار متاسفم. در جهان واقعی این اتفاقات می\u200cافتد و من بسیار متاسفم.  این تنیسور مطرح جهان گفت: ما مردم بسیار خوش\u200cشانسی هستیم که می\u200cتوانیم از تجربیات شگفت\u200cانگیز لذت ببریم زیرا تنیس\u200cباز هستیم، حتی اگر شنیدن آن وحشتناک باشد، باید برای آن آماده باشیم. باید برابر چنین مسائلی که ممکن است در هنگام مواجهه با مردم اتفاق بیفتد مقاومت کنیم. هیچ چیز در این زندگی عالی نیست؛ ما باید اینگونه باشیم، آماده برای سختی\u200cها. نادال یادآور شد: من درک می\u200cکنم که احتمالا نائومی با این نوع مسائلی که دارد، مشکلات زیادی را متحمل شده است. تنها چیزی که برای او آرزو می\u200cکنم بهبودی است. برای او بهترین\u200cها را آرزو دارم.\xa0 انتهای پیام/\n\n\n',
#   'tags': ['رافائل نادال', 'تنیس باز مطرح جهان', 'تنیس', 'تبعیض نژادی'],
#   'date': '3/15/2022 12:13:47 PM',
#   'url': 'https://www.farsnews.ir/news/14001224000484/واکنش-اهالی-تنیس-به-تبعیض-نژادی-نادال-باید-برای-سختی\u200cها-آماده-باشیم',
#   'category': 'sports'},
#  '21': {'title': 'توضیحات معاون باشگاه استقلال در مورد آخرین وضعیت چمن کمپ حجازی',
#   'content': '\nبه گزارش خبرگزاری فارس، سعید فتاحی معاون اجرایی باشگاه استقلال، در گفت\u200cوگو با رسانه این باشگاه، در خصوص آخرین وضعیت چمن کمپ مرحوم حجازی، اظهار داشت: بعد از کارشناسی انجام شده، مقرر شد با تکنولوژی روز، چمن جدید کاشته شود و سیستم مکانیزه آبیاری هم در این مجموعه نصب شود.\xa0 وی افزود: در حال حاضر عملیات خاکبرداری به عمق ۷۰ سانتی\u200cمتر در این کمپ انجام شده و عملیات شن\u200cریزی، زیرسازی و زهکشی اصولی به صورت شبانه\u200cروزی در حال انجام است. ان\u200cشاءالله بعد از این اقدامات، زمین آماده کاشت چمن می\u200cشود. تلاش می\u200cکنیم بتوانیم هرچه سریعتر از کمپ حجازی بهره\u200cبرداری کنیم.   فتاحی در خصوص وضعیت چمن مجموعه انقلاب هم گفت: عملیات بهسازی چمن این مجموعه به طور کامل انجام شده و ان\u200cشاءالله در سال جدید این مجموعه آماده برگزاری تمرینات استقلال خواهد بود. ضمن اینکه عملیات بهسازی چمن مجموعه آرارات هم همزمان در سال جدید در دستور کار باشگاه استقلال قرار می\u200cگیرد. انتهای پیام/\n\n\n',
#   'tags': ['کمپ حجازی',
#    'چمن کمپ حجازی',
#    'سعید فتاحی',
#    'خاکبرداری چمن کمپ حجازی'],
#   'date': '3/15/2022 12:01:09 PM',
#   'url': 'https://www.farsnews.ir/news/14001224000463/توضیحات-معاون-باشگاه-استقلال-در-مورد-آخرین-وضعیت-چمن-کمپ-حجازی',
#   'category': 'sports'},
#  '22': {'title': 'مسابقات تنیس ایندین\u200cولز| پایان ۳ هفته امپراطوری مدودوف/ جوکوویچ به صدر برمی\u200cگردد',
#   'content': '\nبه گزارش خبرگزاری فارس، مسابقات تنیس ایندین ولز در حالی پیگیری می\u200cشود که دنیل مدودوف روسی با شکستی ناباورانه مقابل مانفیلس به ۳ هفته شماره یک جهان بودن خود پایان داد. مدودوف به حریف فرانسوی خود با نتیجه ۴ -۶، ۶-۳ و ۶-۱ باخت. این شکست بدین معنا که نواک جوکوویچ می\u200cتواند دوباره به صدر برترین تنیس\u200cبازان جهان برگردد.\xa0 مدودوف بعد از این شکست، گفت: قطعا فشاری روی من نیست. فکر می\u200cکردم شماره یک جهان بودن انگیزه بیشتری به من بدهد و البته انگیزه هم داشتم اما در این مسابقه بهترین نبودم. باید تلاش کنم تا عملکرد بهتری داشته باشم.\xa0 در دیگر مسابقات امروز نیک کرگیوس استرالیایی ۲ بر صفر از سد کسپر رود گذشت. استفانو تسیتسیپاس یونانی ۲ بر یک مغلوب بروکسبی شد. پیش از این رافائل نادال به مرحله یک شانزدهم راه یافته بود.\xa0 انتهای پیام/\n\n\n',
#   'tags': ['تنیس',
#    'مسابقات تنیس ایندین\u200cولز',
#    'دنیل مدودوف',
#    'نواک جوکوویچ'],
#   'date': '3/15/2022 12:00:30 PM',
#   'url': 'https://www.farsnews.ir/news/14001224000438/مسابقات-تنیس-ایندین\u200cولز|-پایان-۳-هفته-امپراطوری-مدودوف-جوکوویچ-به-صدر',
#   'category': 'sports'},
#  '23': {'title': 'مدافع پیکان جراحی کرد + عکس',
#   'content': '\nبه گزارش خبرگزاری فارس و به نقل از سایت باشگاه پیکان، ایمان اکبری در دیدار پیکان مقابل فجرسپاسی در هفته بیستم لیگ برتر دچار مصدومیت شدید از ناحیه زانو شد که مشخص شد رباط صلیبی اش دچار پارگی شده و به همین خاطر نیاز به جراحی داشت. این مدافع 21 ساله که یکی از پدیده های تیم فوتبال پیکان در فصل جاری محسوب می\u200cشد، روز گذشته در بیمارستان آتیه تهران زانوی مصدوم خود را جراحی کرد. ایمان اکبری که به خاطر کیفیت نامطلوب زمین حافظیه شیراز دچار این مصدومیت شد، حالا باید دوران نقاهت خود را سپری کند و بعد از مدتی برای بازگشت به لیگ برتر استارت بزند. او در تلاش است تا برای شروع لیگ بعدی آماده حضور در میادین فوتبال شود. انتهای پیام /\n\n\n',
#   'tags': ['ایمان اکبری',
#    'مدافع تیم پیکان',
#    'جراحی رباط صلیبی مدافع تیم پیکان',
#    'پیکان'],
#   'date': '3/15/2022 11:10:14 AM',
#   'url': 'https://www.farsnews.ir/news/14001224000352/مدافع-پیکان-جراحی-کرد--عکس',
#   'category': 'sports'},
#  '24': {'title': 'تمجید رسانه پرتغالی از طارمی؛ ستاره ایرانی استاد پنالتی است +عکس',
#   'content': '\nبه گزارش خبرگزاری فارس، یکشنبه شب در چارچوب هفته بیست و ششم لیگ پرتغال، پورتو به مصاف توندلا رفت و با درخشش طارمی به برتری 4 بر صفر رسید. در این مسابقه طارمی یک پنالتی گرفت و توانست پنالتی خود را به زیبایی وارد دروازه حریف کند.\xa0 درخشش ستاره کشورمان باعث شد تا در این روزها بار دیگر رسانه\u200cهای پرتغالی به تمجید از او بپردازند و عملکرد وی را تحسین کنند. شب گذشته رسانه «ژورنال» پرتغال از زاویه\u200cای دیگر به درخشش طارمی پرداخت و او را «استاد پنالتی» نامید.\xa0  این رسانه با تیتر «پنالتی\u200cهای مشکوک با طارمی رنگ می\u200cبازند» از مهارت او در پنالتی گرفتن و پنالتی زدن صحبت کرد و نوشت: ستاره ایرانی تاکنون هیچ پنالتی در لیگ پرتغال از دست نداده است. طارمی تاکنون 8 پنالتی برای پورتو زده که هر 8 پنالتی به گل بدل شده است. او از زمان حضورش در پرتغال تاکنون 15 پنالتی برای تیمش گرفته که یک آمار عالی محسوب می\u200cشود. پورتو اکنون با 70 امتیاز در صدر جدول لیگ پرتغال قرار دارد و مدعی اصلی قهرمانی محسوب می\u200cشود. اسپورتینگ، نزدیک\u200cترین تعقیب کننده پورتو با 64 امتیاز در رده دوم جای دارد.\xa0 انتهای پیام/\n\n\n',
#   'tags': ['لژیونرها', 'طارمی', 'مهدی طارمی', 'پورتو', 'طارمی پنالتی'],
#   'date': '3/15/2022 10:56:04 AM',
#   'url': 'https://www.farsnews.ir/news/14001224000295/تمجید-رسانه-پرتغالی-از-طارمی-ستاره-ایرانی-استاد-پنالتی-است-عکس',
#   'category': 'sports'},
#  '25': {'title': 'ضرب الاجل فیفا به تیم طارمی ؛ پول بازیکن برزیلی را پرداخت کنید',
#   'content': '\nبه گزارش خبرگزاری فارس، فیفا به باشگاه پورتو اخطار داد تا انتهای ماه مارس (11 فروردین) بدهی باشگاه گرمیو را پرداخت کند. پورتو سال گذشته «په په»، مهاجم برزیلی را از باشگاه گرمیو با 15 میلیون خریداری کرد ولی هنوز قسط\u200cهای آن را نداده است. گلوب اسپورت برزیل گزارش داد که شکایت\u200cهای گرمیو پاسخ داده و فیفا به پورتو اخطار داده که هر چه سریع بدهی خود را پرداخت کند. طبق گزارش رسانه\u200cهای پرتغالی مبلغ مورد بحث مربوط به سومین قسط از 5 قسط پورتو به گرمیو است. این تیم باید تا دسامبر 2021 قسط سوم خود را پرداخت می\u200cکرد. حالا با تاخیر به وجود آمده باید ضمن پرداخت قسط ، 2.5 میلیون یورو نیز به عنوان جریمه پرداخت کند.\xa0 انتهای پیام/\n\n\n',
#   'tags': ['فیفا', 'پورتو', 'جریمه پورتو', 'په په'],
#   'date': '3/15/2022 10:53:09 AM',
#   'url': 'https://www.farsnews.ir/news/14001224000317/ضرب-الاجل-فیفا-به-تیم-طارمی-پول-بازیکن-برزیلی-را-پرداخت-کنید',
#   'category': 'sports'},
#  '26': {'title': 'تیروکمان قهرمانی آسیا| صعود همه کمانداران به دور دوم',
#   'content': '\nبه گزارش خبرگزاری فارس، رقابت\u200cهای تیراندازی با کمان کاپ آسیایی تایلند صبح امروز در دو ماه ریکرو مردان و کامپوند بانوان آغاز شد. نتایج کمانداران کشورمان به شرح زیر است: رضا شبانی در مرحله مقدمانی ریکرو مردان با امتیاز 643 در رده دهم قرار گرفت. وی در دور نخست مسابقات حذفی به مصاف کمانداری از قزاقستان رفت و با نتیجه 6 بر 4 به برتری رسید. وی در دور یک هشتم نهایی روز جمعه به مصاف کمانداری از بنگلادش می\u200cرود. محمدحسین گلشنی در مرحله مقدمانی ریکرو مردان با امتیاز 642 در رده سیزدهم قرار گرفت. وی در دور نخست مسابقات حذفی به مصاف کمانداری از مالزی رفت و با نتیجه 7 بر یک به برتری رسید. وی روز جمعه باید با کمانداری از مالزی دیدار کند. ارشک فاضل در مرحله مقدمانی ریکرو مردان با امتیاز 622 در رده بیست و دوم قرار گرفت. وی در دور نخست مسابقات حذفی به مصاف کمانداری از فیلیپین رفت و با نتیجه 6 بر 2 به برتری رسید. وی روز جمعه باید به کمانداری از قزاقستان دیدار کند. گیسا بایبوردی در مرحله مقدماتی کامپوند بانوان با امتیاز 689 در رده نخست ایستاد. وی در دور نخست مسابقات حذفی استراحت دارد و روز جمعه در مرحله یک هشتم نهایی با کمانداری از بنگلادش بازی خواهد کرد. ویدا حلیمیان در مرحله مقدماتی کامپوند بانوان با امتیاز 677 در رده یازدهم ایستاد. وی در دور نخست مسابقات حذفی به مصاف کمانداری از مالزی رفت و با نتیجه 138 بر 136 به پیروزی رسید. وی در دور یک هشتم نهایی روز جمعه به مصاف کمانداری از هند می\u200cرود. کوثر خشنودی\u200cکیا در مرحله مقدماتی کامپوند بانوان با امتیاز 677 در رده دهم ایستاد. وی در دور نخست مسابقات حذفی استراحت دارد و روز جمعه در مرحله یک هشتم نهایی به مصاف کمانداری از هند می\u200cرود. \xa0راحله فارسی در مرحله مقدماتی کامپوند بانوان با امتیاز 669 در رده پانزدهم ایستاد. وی در دور نخست مسابقات حذفی به مصاف نماینده قزاقستان رفت و با نتیجه 143 بر 136 به پیروزی رسید. وی در دور یک هشتم نهایی روز جمعه به مصاف کمانداری از هند می\u200cرود. انتهای پیام/\n\n\n',
#   'tags': ['تیروکمان', 'کامپوند', 'ریکرو', 'رضا شبانی', 'گیسا بایبوردی'],
#   'date': '3/15/2022 10:52:06 AM',
#   'url': 'https://www.farsnews.ir/news/14001224000324/تیروکمان-قهرمانی-آسیا|-صعود-همه-کمانداران-به-دور-دوم',
#   'category': 'sports'},
#  '27': {'title': 'تحلیل سرمربی سابق تنیس از تغییرات و استعفاها در فدراسیون/ احمدوند: شکل اعتراض\u200cها صحیح نبود',
#   'content': '\nسعید احمدوند در گفت\u200cوکو با خبرنگار ورزشی خبرگزاری فارس، در مورد تغییر و تحولات در فدراسیون تنیس و برخی استعفاها در این فدراسیون اظهار داشت: این حق هر رئیس فدراسیون است که در مجموعه کاری خود تغییر و تحول بدهد و با هر کس که دوست دارد کار کند. در همه فدراسیون\u200cها به این شکل است و در گذشته هم از این دست اتفاقات افتاده است. بارها دبیران فدراسیون تغییر کرده\u200cاند، اما به نظرم شکل اعتراضی که از سوی برخی صورت گرفت، می\u200cتوانست منطقی\u200cتر باشد. از آن مهم\u200cتر اینکه وقتی اعتراض گروهی است،\u200c\u200c بهتر است تا آخر همه پای آن بایستند نه اینکه وسط کار نظر خود را تغییر دهند. به هر حال رفتارهای انسانها با یکدیگر متفاوت است. در مجموع من با این شکل اعتراض موافق نبودم و بهتر بود تصمیم دیگری گرفته می\u200cشد. سرمربی سابق تیم ملی تنیس عنوان کرد: عزیزی رئیس فدراسیون بهتر است تغییر را در جاهایی که الزامی\u200cتر است صورت دهد، مثلاً ما در بخش آموزش واقعا ضعیف هستیم و هر چه سریع\u200cتر باید در مورد آن اقدام جدی صورت بگیرد. ما در سطح بسیار پائینی هستیم و اگر فکر می\u200cکنند صمت\u200cهای آسیایی مسئول آموزش فدراسیون می\u200cتواند به این رشته کمک کند، باید گفت این سمت\u200cها هم سال گذشته از دست رفت. وی ادامه داد: رئیس کمیته آموزش در همه جای فدراسیون هست و نمی\u200cدانم چه اصراری است که یک نفر تا این حد همه کارها را انجام دهد. وقتی به این شرایط اعتراض می\u200cکنم دلیلم این است که بازیکنی پیش من آمده که بک\u200cهند و فورهند را بلد نیست، این نشان می\u200cدهد که ما در آموزش ضعیف هستیم. به نظر من، رئیس فدراسیون باید توضیح دهد که چرا این فرد در همه بخش\u200cهای تنیس دخالت می\u200cکند؟ استانی که او خودش تنیس بازی کرده یک بازیکن شاخصی ندارد. من دوست داشتم عزیزی در این بخش هم تغییراتی را ایجاد کند.\xa0  \xa0 وی در مورد اینکه ظاهراً نامه استعفا قبل از رسیدن به دست رئیس فدراسیون در رسانه\u200cها پخش شده است، گفت: این هم یک کار اشتباه بود. من چون خودم تجربه این کار را داشتم می\u200cگویم که بهتر بود ابتدا نامه به دست رئیس فدراسیون می\u200cرسید و بعداً اگر ترتیب اثری داده نمی\u200cشد، به رسانه\u200cها می\u200cدادند. احمدوند در مورد تغییر سرمربی تیم ملی بانوان، گفت: فرناز فصیحی با اختلاف، بهترین مربی ایران است و هیچ\u200cکس به سطح او نمی\u200cتواند نزدیک هم بشود. او شاگردان زیادی را پرورش داده. به نظرم باید در مورد کنار گذاشتن او یک مقدار تجدیدنظر می\u200cشد. انتهای پیام/\n\n\n',
#   'tags': ['احمدوند',
#    'تیم ملی تنیس',
#    'تنیس',
#    'استعفا در تنیس',
#    'فدراسیون تنیس',
#    'داود عزیزی فدراسیون تنیس'],
#   'date': '3/15/2022 10:49:48 AM',
#   'url': 'https://www.farsnews.ir/news/14001224000270/تحلیل-سرمربی-سابق-تنیس-از-تغییرات-و-استعفاها-در-فدراسیون-احمدوند-شکل',
#   'category': 'sports'},
#  '28': {'title': 'گزارش ویژه بوندس لیگا از آزمون / ستاره ایرانی، امید آلمانی\u200cها شد',
#   'content': '\nبه گزارش خبرگزاری فارس، پنج شنبه شب در چارچوب دور برگشت یک هشتم نهایی لیگ اروپا، بایرلورکوزن میزبان آتالانتا خواهد بود. این مسابقه که از ساعت 21:15 برگزار می\u200cشود، در برگامو با نتیجه 3 بر 2 به سود تیم ایتالیایی به پایان رسید. لورکوزن که در این روزها بهترین بازیکنانش را در اختیار ندارد، امیدوار است با ستاره\u200cهای تازه وارد مثل آزمون، گاسپرینی را شکست دهد و راهی مرحله بعدی شود. در همین رابطه سایت بوندس لیگا گزارشی در خصوص این مسابقه نوشت و با عبارت «5 دلیل که لورکوزن می\u200cتواند آتالانتا را شکست دهد» به تمجید از شرایط تیم آلمانی پرداخت.  برای این مسابقه، لورکوزن 2 ستاره بزرگ خود به نام\u200cهای «پاتریک شیک» و «فلوران فیرتس» را در اختیار ندارد. با این حال سایت بوندس لیگا نوشت: نه شیک است و نه فیرتس اما مشکلی نیست. لورکوزن بارها ثابت کرده که بدون شیک نیز می\u200cتواند در خط حمله زهردار ظاهر شود. آنها موسی دیابی را در اختیار دارند که در نبود شیک می\u200cتواند بار گلزنی را به دوش بکشد. او در مسابقه رفت گل دوم تیمش را به ثمر رساند. در ضمن لورکوزن مهاجمان دیگر نیز برای گلزنی در اختیار دارد. آنها لوکاس آلاریو و سردار آزمون که به تازگی راهی این تیم شده را در ترکیب دارند. ستاره ایرانی در لیگ اروپا در زنیت موفق بوده و توانسته آمار خوبی از خود به ثبت برساند. آیا او می\u200cتواند نظر جراردو سیوانه را به خود جلب کند و برای اولین بار در ترکیب اصلی قرار گیرد؟  سایت بوندس لیگا در ادامه گزارش به شروع طوفانی لورکوزن در بازی رفت پرداخت و نوشت: وقتی به بازی آنها در دیدار رفت نگاه می\u200cکنیم، متوجه می\u200cشویم که چقدر آنها بازی را خوب آغاز کردند و با ضربه دیدنی آرانگویس به گل دست یافتند. قطعا حضور او نیز می\u200cتواند کمک کند تا لورکوزن شروعی طوفانی در بازی برگشت داشته باشد. بوندس لیگا در ادامه به تمجید از «هرادسکی»، دروازه\u200cبان این تیم پرداخت و او را کاپیتانی فوق\u200cالعاده خطاب کرد. در ضمن لورکوزن در لیگ اروپا در 25 بازی توانسته به 17 برد دست یابد و از همین امتیاز می\u200cتواند برای شکست آتالانتا استفاده کند. در انتها و در نکته پنجم بوندس لیگا نوشت که جراردو سیوانه مرد بازی\u200cهای بزرگ است. او که سابقا هدایت یانگ\u200cبویز را در اختیار داشت در شب\u200cهای اروپایی نمایش\u200cهای درخشانی از خود به جای گذاشت و حالا می\u200cخواهد این کار را با لورکوزن انجام دهد. انتهای پیام/\xa0\n\n\n',
#   'tags': ['لژیونرها', 'آزمون', 'سردار آزمون', 'بوندس لیگا'],
#   'date': '3/15/2022 10:39:26 AM',
#   'url': 'https://www.farsnews.ir/news/14001224000278/گزارش-ویژه-بوندس-لیگا-از-آزمون--ستاره-ایرانی-امید-آلمانی\u200cها-شد',
#   'category': 'sports'},
#  '29': {'title': 'مدیرعامل آلومینیوم: مرفاوی می\u200cداند هیچ باشگاهی با یک نفر صحبت نمی\u200cکند/استقلالی\u200cها لیگ را گرفته\u200cاند',
#   'content': '\nحمید محرابی در گفت\u200cوگو با خبرنگار ورزشی خبرگزاری فارس، در خصوص انتخاب سیدمهدی رحمتی به عنوان سرمربی جدید تیم فوتبال آلومینیوم اراک اظهار داشت: بعد از نتایج اخیر، هیات مدیره باشگاه به این نتیجه رسید که وضعیت بررسی شود. علیرغم زحمات زیاد رسول خطیبی برای صعود و دو نیم فصلی که تیم را در لیگ برتر هدایت کرد، با توجه به عدم رضایت هیات مدیره از نتایج اخیر قرار شد به صورت توافقی قطع همکاری کنیم. وی افزود: جلسات بعدی هیات مدیره در خصوص گزینه\u200cها بود که بعد از بحث و بررسی، سیدمهدی رحمتی با توجه به برنامه\u200cای که داشت به عنوان سرمربی تیم انتخاب شد. از این انتخاب راضی هستیم و تصمیم اکثریت هیات مدیره است. نه خطیبی در کار ما دخالت و نه ما در کار او دخالت کردیم مدیرعامل باشگاه آلومینیوم در مورد اینکه پس از شکست 4 بر صفر مقابل ذوب\u200cآهن شایعاتی مبنی بر اختلافات درونی تیم مطرح شدند، گفت: فشار روی همه ارکان تیم وجود دارد. اتفاقی که مقابل ذوب آهن افتاد هم اوج فشار بود. بازیکن و مربی پرخاشگری کردند. بازیکن با استرس بازی می\u200cکرد ولی هیچ کوتاهی از جانب بازیکنان و کادرفنی ندیدیم. همه برای کسب بهترین نتیجه تلاش می کردند اما تکراری شدن باخت ها و مساوی\u200cهای مکرر از نظر روحی و روانی روی آن\u200cها اثر گذاشته بود. دچار استرس بودند ولی به این باور نرسیدیم که کسی قصد وغرضی داشته باشد. به همه بازیکنان اعتماد داریم و از کادرفنی هم همیشه حمایت می\u200cکنیم. محرابی در مورد اینکه شایعات دیگری در مورد اختلاف خطیبی با برخی اعضای هیات مدیره به خاطر اعمال نظر و تصمیم در تیم، اظهار داشت: هیچ وقت، هیچ کدام از اعضای هیات مدیره در کار تیم دخالت نکرده، دخالت نمی\u200cکند و دخالت نخواهد کرد. این اعتقاد را داریم که صفر تا صد اختیارات مستطیل سبز با سرمربی و کادرفنی است. به همین مقدار هم اجازه نمی\u200cدهیم کادرفنی در مسائل مدیریتی دخالت کند. هرکسی باید چارچوب وظایف خودش را حفظ کند. نه خطیبی در کار ما دخالتی داشته و نه ما در کار او، این\u200c حرف\u200cها در حد سوتفاهم است. جلالی انتخاب نشد اما به انتخاب ما تبریک گفت وی در مورد گلایه\u200cهای صمدمرفاوی از مذاکره با رحمتی و پورموسوی، گفت: صمد مرفاوی از پیشکسوتان خوب و مربیان با دانش فوتبال کشور است. مرفاوی ملی پوش بوده و باید به او احترام بگذاریم. اما صاحب تجربه است و می\u200cداند که هیچ باشگاهی با یک نفر صحبت نمی\u200cکند. به هیچ فردی هم که طرف مذاکره است، تضمین نمی\u200cدهد. اول فصل هم ما با 23نفر از بزرگان صحبت کردیم که یکی از آن\u200cها مرفاوی بود. مدیرعامل آلومینیوم اراک تصریح کرد: یکی از این بزرگان بعد از انتخاب خطیبی برایم پیام فرستاد و گفت بهترین انتخاب را انجام دادی. اگر من هم بودم این انتخاب را در این شرایط انجام می\u200cدادم چون در آنجا کارکرده، شناخت و انگیزه دارد. او از نظر من خیلی بزرگتر شد که استاد مجید جلالی است. آدم اینطور بزرگ می\u200cشود و ما باید یاد بگیریم. وقت گذاشته، جلسه گذاشتیم، حدود دو ساعت صحبت کردیم اما انتخاب نشده و بعد به ما برای انتخابی که کردیم تبریک می\u200cگوید. این یعنی اوج معرفت، کسوت و رفتار اخلاقی در ورزش، من به چنین تفکری تعظیم می\u200cکنم. محرابی در خصوص اینکه مرفاوی اعلام کرده اینکه مدیران آلومینیوم به او گفته بودند اگر فشاری از جانب کارخانه نباشد سرمربی خواهد شد اما پس از صرف ناهار اعلام شده شما برودی خبرتان می\u200cکنیم، گفت: مساله فشار کارخانه را به شدت تکذیب می\u200cکنم. ما اعضای هیات مدیره فقط مذاکره کردیم و تصمیم را در نشست چندساعته باشگاه گرفتیم. هیچ مذاکره کننده\u200cای به هیچ عنوان با هیچ مذاکره شونده\u200cای کارش را قطعی نمی\u200cکند. فقط چند گزینه داریم، به ترتیب برنامه صحبت می\u200cکنیم و بعد به جمع بندی می\u200cرسیم. اینطور نیست که مثلا با 5نفر صحبت کنیم و به همه آن\u200cها بگوییم شما سرمربی هستید. فقط سوالاتمان را می\u200cپرسیم. زمانی شما یک گزینه دارید و مثلا می\u200cگویید من می\u200cخواهم با صمد مرفاوی ببندم. از او دعوت می کنید و آنجا توافق می\u200cشود. ما مذاکره کردیم و برنامه\u200cها را گرفتیم. وی افزود: اعمال نظری از جانب هیچ کس وجود نداشته، به آقایان هم گفتیم اگر انتخاب شوید هیچ کس شما را به ما سفارش نکرده است. نه هوادار، نه مدیر، نه وزیر و نه وکیل، شما بر اساس شایستگی خودتان انتخاب شدید بنابراین خودتان را بدهکار کسی ندانید. کسی به شما زنگ نزند بگوید من سفارش کردم. ما تصمیم می\u200cگیریم و هیچ کس دیگری در این مورد دخالت نمی\u200cکند. در فضایی که داریم کسی برای این کارها ورود نمی\u200cکند. از کارخانه به مجموعه ما کاری ندارند و نم ...
#   'tags': ['لیگ برتر فوتبال ایران',
#    'سیدمهدی رحمتی',
#    'حمید محرابی',
#    'آلومینیوم اراک',
#    'مدیرعامل آلومینیوم اراک',
#    'گلایه مرفاوی از آلومینیوم اراک'],
#   'date': '3/15/2022 10:36:59 AM',
#   'url': 'https://www.farsnews.ir/news/14001224000282/مدیرعامل-آلومینیوم-مرفاوی-می\u200cداند-هیچ-باشگاهی-با-یک-نفر-صحبت-نمی\u200cکند',
#   'category': 'sports'},
#  '30': {'title': '۳ قایقران ایران به مسابقات قهرمانی آسیا اعزام شدند',
#   'content': '\nبه گزارش خبرگزاری فارس، تیم اسلالوم ایران با ترکیب 3 قایقران و یک مربی بامداد امروز برای حضور در مسابقات قهرمانی آسیا عازم تایلند شد. مسابقات اسلالوم قهرمانی آسیا 29 اسفند تا 2 فروردین در پاتایا تایلند برگزار می\u200cشود.\xa0 اسفندیار شیرمحمدی مربی تیم ملی اسلالوم در این رقابت\u200cهاست و نیروانا اسدبیگی در بخش کانواسلالوم بانوان، محدثه حسن\u200cپور در کایاک اسلالوم بانوان و محمد مهدوی\u200cنیا در کانواسلالوم مردان نمایندگان کشورمان در مسابقات اسلالوم قهرمانی آسیا هستند. کتایون اشرف نایب رئیس فدراسیون قایقرانی و داور بین\u200cالمللی اسلالوم ایران نیز به عنوان داور در این رقابت\u200cها حضور دارد. انتهای پیام/\n\n\n',
# ...
#   'tags': ['باشگاه پرسپولیس', 'باشگاه پدیده', 'بدهی پرسپولیس به باشگاه پدیده'],
#   'date': '3/1/2022 4:16:10 PM',
#   'url': 'https://www.farsnews.ir/news/14001210000442/اعتراض-شدید-باشگاه-پدیده-به-باز-بودن-پنجره-پرسپولیس-به-AFC-و-فیفا',
#   'category': 'sports'},
#  '988': {'title': 'افشاگری لیون از علاقه سرمربی لیون به آزمون / یا سردار یا هیچ مهاجم دیگر',
#   'content': '\nبه گزارش خبرگزاری فارس، باشگاه لیون در پنجره زمستانی قصد داشت یک مهاجم به ترکیب خود اضافه کند و چندین پیشنهاد نیز داشت که در انتها تصمیم گرفت که با «موسی دمبله»، مهاجم وقت خود ادامه دهد. داستان از این قرار بود که «پیتر بوش» تنها می\u200cخواست سردار آزمون خریداری شود و به همین دلیل با خرید هیچ مهاجم دیگری موافقت نکرد. باشگاه لیون در زمستان تمام توان خود را برای خرید آزمون از زنیت به کار گرفت ولی این باشگاه لورکوزن بود که توانست در انتها ستاره کشورمان را خریداری کند تا آزمون به جای رسیدن به لوشامپیونه به بوندس لیگا برسد.  وینسین پونسوت، مدیر ورزشی باشگاه لیون در مصاحبه با اکیپ گفت: پیتر بوش فقط آزمون را می\u200cخواست. وقتی دیدیم که نمی\u200cتوانیم سردار را به خدمت گیریم برای همین مهاجمان دیگری پیشنهاد دادیم. او ولی به جای خرید مهاجمی دیگر گفت یا آزمون و یا هیچ بازیکن. او ترجیح داد با موسی دمبله ادامه دهد. لیون البته در پنجره زمستانی توانست تانگای اندومبله و رومین فایوره را نیز خریداری کند ولی در جذب آزمون ناکام ماند. انتهای پیام/\n\n\n',
#   'tags': ['سردار آزمون',
#    'آزمون',
#    'بوش',
#    'پیتر بوش',
#    'لورکوزن',
#    'بایرلورکوزن',
#    'لیون'],
#   'date': '3/1/2022 4:06:26 PM',
#   'url': 'https://www.farsnews.ir/news/14001210000436/افشاگری-لیون-از-علاقه-سرمربی-لیون-به-آزمون--یا-سردار-یا-هیچ-مهاجم',
#   'category': 'sports'},
#  '989': {'title': 'شکایت باشگاه نساجی از استقلال به خاطر استفاده از ژستد و یامگا',
#   'content': '\nبه گزارش خبرنگار ورزشی خبرگزاری فارس، بعد از دیدار نساجی و استقلال باشگاه مازندرانی از 2 بازیکن تیم استقلال رودی ژستد و کوین یامگا شکایت کرد. باشگاه نساجی اعتقاد دارد پروانه کار هر دو بازیکن تیم استقلال به پایان رسیده و به همین دلیل نباید در دیدار روز گذشته از آنها استفاده می شد. مشابه این اتفاق در دیدار رفت دو تیم افتاد و هواداران نساجی به دلیل اینکه مسئولان باشگاه از ژستد و یامگا به دلیل داشتن مجوز موقت شکایت نکردند نسبت به عوامل باشگاه خود موضع گیری شدیدی به عمل آوردند. دیدار تیم های نساجی و استقلال شب گذشته با تساوی بدون گل به پایان رسید. انتهای پیام/\n\n\n',
#   'tags': ['باشگاه استقلال',
#    'نساجی',
#    'رودی ژستد',
#    'کوین یامگا',
#    'شکایت نساجی از 2 بازیکن استقلال'],
#   'date': '3/1/2022 3:42:53 PM',
#   'url': 'https://www.farsnews.ir/news/14001210000413/شکایت-باشگاه-نساجی-از-استقلال-به-خاطر-استفاده-از-ژستد-و-یامگا',
#   'category': 'sports'},
#  '990': {'title': 'واکنش ناظم الشریعه به حضور در تیم ملی فوتسال عراق',
#   'content': '\nسید محمد ناظم الشریعه در گفت\u200cوگو با خبرنگار ورزشی فارس در مورد سفرش به عراق اظهار داشت: به درخواست وزارت ورزش عراق سفری به این کشور داشتم. صبح امروز هم در دیداری با وزیر ورزش عراق در مورد طرح توسعه آموزش و.. فوتسال صحبت هایی کردیم. سرمربی سابق تیم ملی فوتسال گفت: در این جلسه در مورد نحوه آموزش و پیشرفت فوتسال در عراق حرف هایی زدیم.\xa0 با توجه به اینکه\xa0 ایران به عنوان یک برند در فوتسال دنیا شناخته شده است هر دو کشور می توانند در عرصه آموزش، مربیگری و... حتی تغییر تفکر و.. همکاری هایی داشته باشند. وی در پاسخ به این سوال که به عنوان سرمربی تیم ملی عراق معرفی شده، گفت: صحبتهایی مطرح شده و هیچ چیزی روی کاغذ نیامده اما فعلا فقط با توجه به صحبتهایی که با وزیر ورزش عراق داشتیم\xa0 بر روی طرح توسعه و اموزش و... تمرکز داریم.\xa0 انتهای پیام/\n\n\n',
#   'tags': ['ناظم', 'طرح توسعه', 'فوتسال', 'وزیر ورزش'],
#   'date': '3/1/2022 3:35:22 PM',
#   'url': 'https://www.farsnews.ir/news/14001210000405/واکنش-ناظم-الشریعه-به-حضور-در-تیم-ملی-فوتسال-عراق',
#   'category': 'sports'},
#  '991': {'title': 'انتقاد تند از آرسنال به خاطر نخریدن طارمی +عکس',
#   'content': '\nبه گزارش خبرگزاری فارس، رسانه hitc در گزارشی به انتقاد از سران آرسنال پرداخت که چرا در زمستان «مهدی طارمی» را جذب نکرده\u200cاند. hitc نوشت: بازیکنی که آرسنال دست رد به سینه او زد، در 9 بازی اخیر ، 6 گل زده و 5 پاس گل داده است. این تیم در زمستان مهدی طارمی می\u200cتوانست خریداری کند ولی این کار را انجام نداد و علاوه بر آن فلوریان بلوگان را به صورت قرضی به میدلزبرو فرستاد و اجازه داد که پیر امریک اوبامیانگ به سادگی راهی بارسلونا شود.  رسانه انگلیسی شدیدا به انتقاد از سران توپچی پرداخت و نوشت: این اتفاق\u200cها در حالی رخ داد که قرارداد 2 مهاجم کنونی آرسنال یعنی الکساندر لاکازت و ادی انکتیا در تابستان به پایان می\u200cرسد و آنها می\u200cخواهند تیم را به مقصد جایی دیگر ترک کنند. آرسنال اکنون با اینکه شرایط مناسبی پیدا کرده و توانسته به یکی از مدعیان رسیدن به رده چهارم لیگ برتر نام گیرد ولی با مشکل مهاجم روبه\u200cرو است و باید ستاره\u200cای در خط حمله خریداری کند. آنها به دنبال ولاهوویچ نیز بودند که این بازیکن با رد پیشنهاد آرسنال راهی تورین و یوونتوس شد. انتظار می\u200cرود الکساندر ایزاک، مهاجم سوئدی رئال سوسیداد تابستان راهی امارات شود. از طرف دیگر اوبامیانگ به دلیل انضباطی از تیم کنار گذاشته شد، اکنون آماری خیره کننده در بارسلونا به ثبت رسانده است و توانسته به مهره اصلی ژاوی در احیای کاتالونیا نام گیرد. انتهای پیام/\xa0\n\n\n',
#   'tags': ['طارمی', 'مهدی طارمی', 'آرسنال', 'اوبامیانگ'],
#   'date': '3/1/2022 3:25:50 PM',
#   'url': 'https://www.farsnews.ir/news/14001210000400/انتقاد-تند-از-آرسنال-به-خاطر-نخریدن-طارمی-عکس',
#   'category': 'sports'},
#  '992': {'title': 'اولین تمرین مهاجم خارجی در جمع بازیکنان پرسپولیس +عکس',
#   'content': '\nبه گزارش خبرگزاری فارس، عضو جدید سرخپوشان تهران اولین تمرین خودش در جمع شاگردان یحیی گل محمدی را پشت سر گذاشت. شرزود تمیروف، مهاجم ازبکستانی پرسپولیس که به تازگی با قراردادی به مدت یک فصل و نیم پیراهن قرمز را بر تن کرده، امروز در تمرین حاضر شد تا کارش را رسما با این تیم آغاز کرده باشد.   انتهای پیام/\n\n\n',
#   'tags': ['لیگ برتر فوتبال ایران', 'پرسپولیس', 'شرزود تمیروف'],
#   'date': '3/1/2022 2:34:06 PM',
#   'url': 'https://www.farsnews.ir/news/14001210000353/اولین-تمرین-مهاجم-خارجی-در-جمع-بازیکنان-پرسپولیس-عکس',
#   'category': 'sports'},
#  '993': {'title': 'قهرمانی مس سونگون در لیگ برتر شیرجه',
#   'content': '\nاخبار شرکت ها- به گزارش مس پرس؛ رقابت\u200cهای لیگ برتر شیرجه سال 1400 با قهرمانی تیم مس سونگون به پایان رسید و مس سونگون با 178 امتیاز قهرمان این دوره از مسابقات شد و در مقام نخست ایستاد. گفتنی است مرحله دوم مسابقات هفتم و هشتم اسفند ماه به میزبانی استخر بین\u200c\u200cالمللی مجموعه ورزشی شهید شیرودی انجام شد و تیم\u200cهای رعد پدافند و آرسن البرز نیز به ترتیب با امتیازهای 152 و 91 در رده\u200cهای دوم و سوم قرار گرفتند. انتهای پیام/\n\n\n',
#   'tags': ['قهرمانی', 'لیگ', 'اخبار', '۱۷۸'],
#   'date': '3/1/2022 2:32:33 PM',
#   'url': 'https://www.farsnews.ir/news/14001210000354/قهرمانی-مس-سونگون-در-لیگ-برتر-شیرجه',
#   'category': 'sports'},
#  '994': {'title': 'امیری: جدایی عنایتی شایعه است/در مورد مرادی طبق آیین\u200cنامه باشگاه رفتار می کنیم',
#   'content': '\nبهرام امیری در گفت\u200cوگو با خبرنگار ورزشی خبرگزاری فارس، در خصوص ادامه روند خوب نتیجه\u200cگیری تیم هوادار و کسب امتیاز مقابل تیم فولاد خوزستان اظهار داشت: باشگاه هوادار طبق هدفگذاری، تلاش کرد در نیم\u200cفصل اول جایگاهش را در جدول حفظ کند تا به عنوان فانوس به دست دیده نشود و توانست به اهدافش برسد. در نیم\u200cفصل سعی کردیم با جذب نفرات جدید شرایط خودمان را بهتر کنیم. با تلاش و همت مالکیت، مدیریت، کادر فنی و بازیکنان توانستیم خودباوری را در وجود تک تک بچه\u200cها قرار بدهیم و حالا تیم ما نه تنها زنگ تفریح نیست بلکه برای همه تیم\u200cها یک خطر است. وی افزود: تمام تیم\u200cها وقتی جلوی ما حاضر می\u200cشوند نه تنها به این فکر نمی\u200cکنند که حتما باید ما را شکست بدهند بلکه به این فکر می\u200cکنند؛ مقابل ما از قبل بازنده نباشند. تیم فولاد هم از این قاعده مستثنی نبود. قهرمان سوپرجام ایران دیروز مقابل ما موقعیت آنچنانی نداشت و نتوانست اقتداری را که در بازی\u200cهای قبل داشت را نشان بدهد. بچه\u200cهای ما توانستند یکی از بازی\u200cهای خوبشان را انجام بدهند. مدیرعامل باشگاه هوادار در مورد مطرح شدن شایعاتی پیرامون جدایی رضا عنایتی در پایان فصل عنوان کرد:\u200c باید از کسانی که این شایعات را پخش می\u200cکنند سوال کنید. ما نه با هم مشکلی داریم نه حرفی رد و بدل شده، رضا عنایتی هر روز با من در تماس است. چه زمانی که خوب نتیجه نمی\u200cگرفت و چه الان که خوب نتیجه می\u200cگیرد هیچ صحبتی برای جدایی مطرح نبوده، همیشه به عنوان یک مجموعه خوب در کنار هم بودیم. مدیریت به رضا عنایتی اعتقاد دارد و او هم به مجموعه اعتقاد دارد. این حرف\u200cها شایعاتی بیش نیست. وی در مورد حضور بابک مرادی در یک برنامه تلویزیونی و اینکه گفته می\u200cشود با توجه به ممنوع\u200cالمصاحبه بودن بازیکنان هوادار، مرادی با کسر قرارداد جریمه خواهد شد گفت: اجازه بدهید مدیریت باشگاه بر اساس قرارداد و آیین\u200cنامه تصمیم بگیرد. کمیته انضباطی باشگاه در این مورد تصمیم می\u200cگیرد و طبق قرارداد عمل می\u200cکند. شاید بابک مرادی از سرمربی یا مدیر رسانه مجوز داشته، ما این\u200cها را نمی\u200cدانیم. این مسائل باید در باشگاه و کمیته انضباطی بررسی شود. نه تنها بابک مرادی بلکه هر کسی مجوز نداشته باشد باید جوابگو باشد. همانطور که در قراردادها بندهایی برای پاداش وجود دارد، بندهایی هم وجود دارد که بازیکن مکلف است در چارچوب حرکت کند. چون من اطلاعات دقیقی ندارم و نمی\u200cتوانم اظهار نظر کنم. امیری افزود: بابک مرادی صحبت کرده و من حرف\u200cهای او را نشنیده\u200cام. در مورد هر حرفی هم که زده خودش جوابگو خواهد بود. باید اول ببینیم آیا او مجوز مصاحبه داشته یا خیر. بعد در جزئیات مصاحبه\u200cاش ببینیم چه حرف\u200cهایی زده تا بتوانیم تصمیم بگیریم. مرادی یکی از بازیکنان با ارزش ما است. شخصا برای او احترام قائلم اما اینجا باشگاه هوادار است و قانون دارد. همه ما از خود من تا سایرین باید در چارچوب حرکت کنیم. همانطور که قبلا هم طبق ضوابط و مقررات عمل کرده\u200cایم در این مورد هم همینطور عمل خواهیم کرد. انتهای پیام/\n\n\n',
#   'tags': ['بهرام امیری',
#    'باشگاه هوادار',
#    'بابک مرادی',
#    'هوادار تهران',
#    'مدیرعامل هوادار',
#    'فولاد خوزستان'],
#   'date': '3/1/2022 2:29:27 PM',
#   'url': 'https://www.farsnews.ir/news/14001210000328/امیری-جدایی-عنایتی-شایعه-است-در-مورد-مرادی-طبق-آیین\u200cنامه-باشگاه-رفتار',
#   'category': 'sports'},
#  '995': {'title': 'سرنوشت ایتالیا در دربی امشب میلان/ واکنش مطبوعات به تقابل میلان ـ اینتر',
#   'content': '\nبه گزارش خبرگزاری فارس، امشب از ساعت ۲۳ و ۳۰ دقیقه ورزشگاه سن سیرو میزبان دربی میلان خواهد بود تا یکی از مهمترین جدال\u200cهای فصل ایتالیا رقم خورد. امشب دور رفت نیمه نهایی کوپا ایتالیا بین میلان و اینتر برگزار خواهد شد که به گفته روزنامه کوریره دلا اسپورت می\u200cتواند سرنوشت همه چیز را مشخص کند. میلان و اینتر در کنار ناپولی و حتی یوونتوس جزو مدعیان اصلی کسب اسکودتو در این فصل هستند و امشب باید رقابتی بزرگ با هم برگزار کنند.  گازتا دلا اسپورت در جلد امروز خود دربی امشب را «دربی چربی» نامید و مدعی شد که امشب کارناوالی پر از هیجان به راه افتاده است و همه منتظر دیدن این مسابقه هستند. کوریره دلا اسپورت در جلد امروز مدعی شد که این مسابقه سرنوشت اسکودتو را نیز مشخص خواهد کرد و همه چیز در این مسابقه خواهد بود.  توتو اسپورت نیز از یک بازی هیجانی صحبت کرد و نمایش امروز میلان و اینتر را بسیار پراهمیت دانست. طبق پیش\u200cبینی\u200cها میلان با همان سیستم 1-3-2-4 خود وارد بازی خواهد شد و اینترمیلان با سیستم 2-5-3 مقابل آنها خواهد ایستاد. از مهمترین مصدومان این مسابقه می\u200cتوان به زلاتان و کیائر در میلان اشاره کرد و از آنخل کورئا در اینترمیلان گفت. ترکیب احتمالی برای مسابقه امشب به شرح زیر است: میلان: مانیان ـ فلورنتزی ـ توموری ـ رومانیولی ـ هرناندز ـ بن ناصر ـ کسیه ـ مسیاس ـ کرونیچ ـ لیائو و ژیرو اینتر: هندانوویچ ـ اشکرینیار ـ دی فرای ـ باستونی ـ دامفریز ـ بارلا ـ بروزوویچ ـ چالهان اوغلو ـ پریشیچ ـ ژکو و لائوتارو مارتینز انتهای پیام/\n\n\n',
#   'tags': ['دربی میلان',
#    'اینتر',
#    'میلان',
#    'سری آ',
#    'اسکودتو',
#    'مارتینز',
#    'لائوتارو',
#    'ژکو',
#    'زلاتان'],
#   'date': '3/1/2022 2:09:56 PM',
#   'url': 'https://www.farsnews.ir/news/14001210000333/سرنوشت-ایتالیا-در-دربی-امشب-میلان-واکنش-مطبوعات-به-تقابل-میلان-ـ',
#   'category': 'sports'},
#  '996': {'title': 'رئیس فدراسیون جودو در عراق حاضر شد',
#   'content': '\nبه گزارش خبرگزاری فارس و به نقل از روابط عمومی فدراسیون جودو، آرش میراسماعیلی رئیس فدراسیون جودو، صدیقه کعبی زاده دبیرکل، بابک مهاجری رئیس کمیته داوران صبح امروز\u200c با استقبال سید سمیر صاق الموسوی رئیس فدراسیون جودو کشور عراق، علی نظار شریف رئیس هیات جودو نجف،ابویاسر رئیس هیات جودو کربلا وارد کشور عراق شد. بابک مهاجری رئیس کمیته داوران کشورمان نیز جهت برگزاری سمینار داوری به عراق سفر کرده است. این سفر در راستای امضا تفاهم نامه ورزشی که بین فدراسیون های جودو ایران و عراق امضا شده، صورت گرفت.\xa0 فدراسیون\u200cهای جودو دو کشور ایران و عراق روز\u200c یک شنبه 24 بهمن ماه 1400 در محل فدراسیون تفاهم \u200cنامه همکاری\u200cهای بلند مدت فیمابین امضا کردند و پس از آن اردوی مشترک تیم ملی ایران،عراق و تونس در شهر کربلا آغاز و در حال پیگیری است. انتهای پیام/\n\n\n',
#   'tags': ['فدراسیون', 'عراق', 'عراقی', 'نجف'],
#   'date': '3/1/2022 1:44:14 PM',
#   'url': 'https://www.farsnews.ir/news/14001210000310/رئیس-فدراسیون-جودو-در-عراق-حاضر-شد',
#   'category': 'sports'},
#  '997': {'title': 'دردسر جدید تیم\u200cهای بزرگ ایتالیا ؛ نقض قانون «فیرپلی مالی» به خاطر کرونا',
#   'content': '\nبه گزارش خبرگزاری فارس، نشریه گازتا دلا اسپورت ایتالیا در گزارش امروز خود مدعی شد که یوفا به 3 باشگاه سری\u200cآ هشدار داده که نگاهی ویژه به مسئله «فیرپلی مالی» و به عبارتی توجه به دخل و خرج خود بیاندازند. یوفا تحقیقات خود را برای مسئله مالی باشگاه\u200cهای پس از دوران پاندمی کرونا آغاز کرده و نتیجه آن این شده است که 30 باشگاه اروپایی نتوانند مجوز لازم برای گذراندن استانداردهای مالی باشگاه\u200cها را کسب کنند. در این لیست باشگاه\u200cهایی چون اینتر، میلان و رم دیده می\u200cشود که شاید یوونتوس نیز به جمع آنها اضافه شود. پس از تعطیلی فوتبال به خاطر کرونا در اوایل سال 2020 و بسته ورزشگاه\u200cها ، تیم\u200cها با مشکل بزرگ اقتصادی روبه\u200cرو شدند و نتوانستند دخل و خرج خود را به حالت استاندارد و تعادل برسانند. پس از گذشت بیش از 2 سال آغاز پاندمی کرونا یوفا تحقیقات خود را آغاز کرده و می\u200cخواهد تیم\u200cهای بدون فیرپلی مالی را جریمه کند. یوفا البته لطفی در حق تیم\u200cها انجام داده و بازه زمانی بررسی حساب\u200cهای مالی باشگاه\u200cها را از 3 سال به چهار سال افزایش داده است تا میانگین ضررهای سالیانه باشگا\u200cه\u200cها کاهش یابد. علاوه بر این یوفا اعلام کرده که باشگاه\u200cها مجازند که تا 30 میلیون یورو تراز منفی داشته باشند. با این حال گازتا دلا اسپورت گزارش داده که 30 باشگاه هنوز نتوانسته اند مجوز استاندارد را دریافت کنند. انتهای پیام/\n\n\n',
#   'tags': ['یوفا', 'سری آ', 'یوونتوس', 'میلان', 'اینترمیلان', 'فیرپلی مالی'],
#   'date': '3/1/2022 1:32:04 PM',
#   'url': 'https://www.farsnews.ir/news/14001210000293/دردسر-جدید-تیم\u200cهای-بزرگ-ایتالیا-نقض-قانون-فیرپلی-مالی-به-خاطر-کرونا',
#   'category': 'sports'},
#  '998': {'title': 'عذرخواهی غفوری از مجیدی و بازیکنان استقلال',
#   'content': '\nبه گزارش خبرنگار ورزشی خبرگزاری فارس، تمرین امروز تیم فوتبال استقلال از ساعت 13 در زمین مجموعه ورزشی آرارات برگزار شد و\xa0 ووریا غفوری که در دو بازی اخیر استقلال به دلیل مسائل انضباطی غایب بود امروز بعد از حضور در محل تمرین با عذرخواهی از کادر فنی و بازیکنان کارش را دوباره با این تیم آغاز کرد. این بازیکن در یکی از تمرینات استقلال بعد از برخورد با هم تیمی اش بدون توجه به شرایط تمرین بی اطلاع راهی رختکن شد. تمرین تیم استقلال در حال برگزاری است. انتهای پیام/\n\n\n',
#   'tags': ['فرهاد مجیدی',
#    'تمرین استقلال',
#    'ووریا غفوری',
#    'عذرخواهی غفوری از مجیدی و بازیکنان استقلال'],
#   'date': '3/1/2022 1:13:23 PM',
#   'url': 'https://www.farsnews.ir/news/14001210000275/عذرخواهی-غفوری-از-مجیدی-و-بازیکنان-استقلال',
#   'category': 'sports'},
#  '999': {'title': 'سرمربی سابق تیم ملی فوتسال کشورمان در یک قدمی هدایت تیم ملی عراق',
#   'content': '\nبه گزارش خبرگزاری فارس، شبکه تلویزیونی «الرابعه الریاضیه» خبر داد که ناظم الشریعه در آستانه سرمربیگری تیم ملی فوتسال عراق قرار گرفته است. این رسانه عراقی نوشت: ناظم الشریعه، چهارمین مربی برتر دنیا به بغداد سفر کرده تا هدایت تیم ملی فوتسال عراق را برععده گیرد. ناظم الشریعه، سرمربی سابق تیم ملی فوتسال کشورمان سابقه 2 قهرمانی در رقابت\u200cهای جام ملت\u200cهای آسیا را در اختیار دارد. او با تیم ملی کشورمان در جام جهانی 2016 به مقام سومی رسید.  \xa0 انتهای پیام/ \xa0 \xa0\n\n\n',
#   'tags': ['ناظم الشریعه', 'تیم ملی فوتسال ایران', 'تیم ملی فوتسال عراق'],
#   'date': '3/1/2022 1:10:21 PM',
#   'url': 'https://www.farsnews.ir/news/14001210000277/سرمربی-سابق-تیم-ملی-فوتسال-کشورمان-در-یک-قدمی-هدایت-تیم-ملی-عراق',
#   'category': 'sports'},
#  ...}

# %%
data_tmp = []
for i in tqdm(range(len(data))):
    doc = data[f'{i}']
    content = {
        "content_title":doc['content']
    }
    title = {
        "content_title":doc['title']
    }
    data_tmp.append(content)
    data_tmp.append(title)
# Out:
# 100%|██████████| 12202/12202 [00:00<00:00, 363667.29it/s]

# %%
def load_data_to_elastic(es,data,index_name):
    data_bulk = [
        {
            "_index" : index_name,
            "_id" : i + 1,
            "_source": data[i]
        }
        for i in range(len(data))
    ]
    resp = helpers.bulk(
        es,
        data_bulk,
        index = index_name
    )
    print(resp)

# %% [markdown]
# ### Section One
# In this section, we start our work with a minimum implementation. To begin with, specify your [mapping explicitly](https://www.elastic.co/guide/en/elasticsearch/reference/current/explicit-mapping.html). By default, after uploading documents to your index, Elasticsearch uses type inference to specify the type of each field in your request and then, creates a special index for each of them. To optimize this process, It is better to use explicit mapping and specify the type of each field. Also, you can define [analyzers](https://www.elastic.co/guide/en/elasticsearch/reference/current/analyzer-anatomy.html) and do text processing.
# At this point, fill the TODO parts by considering the following points:
# 1. In the **index** part, define a [char_filter](https://www.elastic.co/guide/en/elasticsearch/reference/current/analysis-charfilters.html) that replaces zero-width non-joiners (nim fasele) with an ASCII space.
#
# 2. In the **index** part, define an analyzer that extracts **Trigrams** and **Bigrams** from the text. You can define a [shingle](https://www.elastic.co/guide/en/elasticsearch/reference/current/analysis-shingle-tokenfilter.html) filter and then use it in your analyzer.
#
# 3. In the mapping part, just define a field named **content_title**. use the analyzer defined in the **index** part to store your documents in the form of **N-grams**. You can store and index a field in multiple ways with different analyzers. See [Multi-fields with multiple analyzers](https://www.elastic.co/guide/en/elasticsearch/reference/current/multi-fields.html#_multi_fields_with_multiple_analyzers)

# %%
sc_mapping = { 
    "settings": {
    "index": {
      "mappings" : [
        "\u200 =>  "
      ]
    }
  },
    "mappings": {
        "properties": {
            #TODO: define your fields here
        }
    }
}

# %%
# Name of index 
sc_index_name = 'ir_test_sc'

# %%
es = Elasticsearch("http://localhost:9200")

# %%
# Delete index if one does exist
if es.indices.exists(index=sc_index_name):
    es.indices.delete(index=sc_index_name)

# Create index
es.indices.create(index=sc_index_name, body=sc_mapping)
# Out:
# /tmp/ipykernel_6752/524072576.py:6: DeprecationWarning: The 'body' parameter is deprecated and will be removed in a future version. Instead use individual parameters.
#   es.indices.create(index=sc_index_name, body=sc_mapping)
# ObjectApiResponse({'acknowledged': True, 'shards_acknowledged': True, 'index': 'ir_test_sc'})

# %%
load_data_to_elastic(es,data_tmp,sc_index_name)
# Out:
# (24404, [])

# %% [markdown]
# The function `get_suggestion` takes an input text (the text which should be corrected) followed by `index_name`. Assign proper values to each parameter (follow the instructions from the PDF). See [phrase suggester](https://www.elastic.co/guide/en/elasticsearch/reference/current/search-suggesters.html#phrase-suggester).

# %%
def get_suggestions(text , index_name):
    resp = es.search(index=index_name,suggest={
        "text": text,
        "simple_phrase": {
            "phrase": {
                "smoothing" : #TODO,
                "field": #TODO,
                "size": #TODO,
                "confidence": #TODO,
                "real_word_error_likelihood": #TODO,
                "max_errors" : #TODO,
                "direct_generator": [ 
                    #TODO 
                ]
            }
        }
    },size=0)
    return dict(resp)

# %%
texts = [
    "لیک برتر فوطبال",
    "تورنومنت شش جانبه",
    "طبعیض نژادی",
    "اردوی طیم امیذ",
    "جام ملب های آشیا",
    "کنره سیاسی آمریکا",
    "انغلاب اشلامی ایران",
    "فدراصیون فوتبال ایران",
    "لایهه مجلص خبرگان",
    "نحبگان دانشگاهی",
    "نمایند مجل",
    "فضاسازی کازب",
    "صلاح ایرادات شورای تگهبان",
    "تهریف های تاریخی",
    "قلیت های دینی",
    "تدارکان لازم",
]

# %%
for text in texts:
    print(get_suggestions(text,sc_index_name )['suggest']['simple_phrase'])
    print("========================")

# %% [markdown]
# ### Section Two
# As you may have noticed, candidates for each token in the input text are generated by [Direct Generators](https://www.elastic.co/guide/en/elasticsearch/reference/current/search-suggesters.html#_direct_generators). Usually, we assume that the user does not have misspellings in the first characters of each term in a sentence. Due to this assumption, the default value of `prefix_length` for each generator is set to 1 to considerably decrease the number of candidates for each token. Though setting this parameter to a higher value decreases response time, we cannot correct misspellings that occur at the beginning of each word. To address this problem, we can set the value of `prefix_length` to zero. It increases the number of candidates for each term. A better alternative is using reversed tokens. After reversing, characters at the beginning of the term are placed at the end of the term so, the misspelled characters will be taken into account by the candidate generator. In the figure below, You can see an example of using reversed tokens for generating better suggestions.
# ![direct_generator.png](data:image/png;base64,...)

# %% [markdown]
# At this point, copy your mapping from the previous section to the TODO part then define another analyzer to reverse tokens (see [Reverse Token Filter](https://www.elastic.co/guide/en/elasticsearch/reference/current/analysis-reverse-tokenfilter.html)). After defining the analyzer, use this analyzer to create another index of `content_title` (do not define another field).

# %%
sc_mapping_v1 = { 
    "settings": {
    "index": {
      #TODO
    }
  },
    "mappings": {
        #TODO
    }
}

# %%
# Name of index 
sc_index_name_v1 = 'ir_test_sc_v1'

# %%
# Delete index if one does exist
if es.indices.exists(index=sc_index_name_v1):
    es.indices.delete(index=sc_index_name_v1)

# Create index
es.indices.create(index=sc_index_name_v1, body=sc_mapping_v1)

# %%
load_data_to_elastic(es,data_tmp,sc_index_name_v1)

# %% [markdown]
# For this part, Copy your TODO part from the previous section to the cell bellow. Add another generator to the `direct_generator` part and use the index of reversed tokens that you have defined in the previous step.
#
# Hint: Use `pre_filter` and `post_filter` in your new generator. See [Direct Generators](https://www.elastic.co/guide/en/elasticsearch/reference/current/search-suggesters.html#_direct_generators)

# %%
def get_suggestions_v1(text , index_name):
    resp = es.search(index=index_name,suggest={
        "text": text,
        "simple_phrase": {
            "phrase": {
                "smoothing" : #TODO,
                "field": #TODO,
                "size": #TODO,
                "confidence": #TODO,
                "real_word_error_likelihood": #TODO,
                "max_errors" : #TODO,
                "direct_generator": [ 
                    #TODO 
                ]
            }
        }
    },size=0)
    return dict(resp)

# %%
for text in texts:
    print(get_suggestions_v1(text,sc_index_name_v1 )['suggest']['simple_phrase'])
    print("========================")

# %% [markdown]
# ### Section Three
# Sometimes, using a synonym of a term in a query will lead to better results. For instance, for the query ***captain usq*** we might generate a candidate ***usa*** for the term
# **usq**, which is a synonym for ***america***. This allows us to present ***captain america*** to the user if this phrase scores high enough. To begin with, for the mapping phase, copy your mappings and settings from the previous section and add another analyzer that maps a term to its synonyms. See [Synonym token filter](https://www.elastic.co/guide/en/elasticsearch/reference/current/analysis-synonym-tokenfilter.html). We have provided the required mappings for you in the file `synonyms.txt`. You should place the file in the directory of Elasticsearch and set the value of `sysnonyms_path` to `synonyms.txt`.

# %%
sc_mapping_v2 = { 
    "settings": {
    "index": {
      #TODO
    }
  },
    "mappings": {
        #TODO
    }
}

# %%
sc_index_name_v2 = 'ir_test_sc_v2'

# %%
# Delete index if one does exist
if es.indices.exists(index=sc_index_name_v2):
    es.indices.delete(index=sc_index_name_v2)

# Create index
es.indices.create(index=sc_index_name_v2, body=sc_mapping_v2)

# %%
load_data_to_elastic(es,data_tmp,sc_index_name_v2)

# %% [markdown]
# For this part, Copy your TODO part from the previous section to the cell bellow. Then define another cadidate generator and use your new analyzer.
#
# HINT: Use `post_filter` in your generator to map generated cadidate tokens to their synonyms.

# %%
def get_suggestions_v2(text , index_name):
    resp = es.search(index=index_name,suggest={
        "text": text,
        "simple_phrase": {
            "phrase": {
                "smoothing" : #TODO,
                "field": #TODO,
                "size": #TODO,
                "confidence": #TODO,
                "real_word_error_likelihood": #TODO,
                "max_errors" : #TODO,
                "direct_generator": [ 
                    #TODO 
                ]
            }
        }
    },size=0)
    return dict(resp)

# %%
for text in texts:
    print(get_suggestions_v2(text,sc_index_name_v2 )['suggest']['simple_phrase'])
    print("====================================")
